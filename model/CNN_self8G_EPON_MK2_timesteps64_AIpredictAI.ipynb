# %%
import pandas as pd 

df = pd.read_csv('./SelfData_thesis/0630_self8GData_3to7_ONU16.csv', usecols=[2])
#df.head()

# %%
maxAi = df['Ai'].max()
maxAi
# Out:
# 423923

# %%
df['Ai'] = df['Ai'] / maxAi #手動正規化
#df['Ri'] = df['Ri'] / 1120017 #手動正規化
print(df[:20])

# 将dataframe 转化为 array
data = df.values
# Out:
#           Ai
# 0   0.000000
# 1   0.030607
# 2   0.032605
# 3   0.000000
# 4   0.000000
# 5   0.000000
# 6   0.000000
# 7   0.039970
# 8   0.019437
# 9   0.073025
# 10  0.037111
# 11  0.033334
# 12  0.047605
# 13  0.007480
# 14  0.010049
# 15  0.023365
# 16  0.025875
# 17  0.010889
# 18  0.023268
# 19  0.022872

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import datetime
import math
import itertools
from sklearn import preprocessing
import datetime
from sklearn.metrics import mean_squared_error
from math import sqrt
# Out:
# C:\Users\joker\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.

# %%
# 1 : 数据切分
result = []
time_steps = 65

for i in range(len(data)-time_steps):
    result.append(data[i:i+time_steps])

result = np.array(result)

# %%
# 训练集和测试集的数据量划分
train_size = int(0.8*len(result))

# 训练集切分
train = result[:train_size,:]

x_train = train[:, :-1]
y_train = train[:, -1][:,-1]
   
x_test = result[train_size:,:-1]
y_test = result[train_size:,-1][:,-1]

feature_nums = len(df.columns)

# 数据重塑
x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1],x_test.shape[2])

print("X_train", x_train.shape)
print("y_train", y_train.shape)
print("X_test", x_test.shape)
print("y_test", y_test.shape)
# Out:
# X_train (10668, 64, 1)
# y_train (10668,)
# X_test (2667, 64, 1)
# y_test (2667,)

# %%
from __future__ import print_function
import math
#importing keras modules
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Activation ,Dropout , Flatten , Conv1D , MaxPooling1D, Input
from tensorflow.keras.layers import LSTM
from tensorflow.keras import losses
from tensorflow.keras import optimizers

#def build_model(input):
#    model = Sequential()
#    model.add(Dense(128,input_shape=(input[0],input[1])))
#    model.add(Conv1D(filters=80,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform"))
#    model.add(MaxPooling1D(pool_size=2,padding='valid'))
#    model.add(Conv1D(filters=48,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform"))
#    model.add(MaxPooling1D(pool_size=2, padding='valid'))
#    model.add(LSTM(32,return_sequences=True))
#    model.add(LSTM(16,return_sequences=False))
#    model.add(Dense(32, activation="relu", kernel_initializer="uniform"))
#    model.add(Dense(1, activation="relu", kernel_initializer="uniform"))
#    model.compile(loss='mse',optimizer='adam',metrics=['mae'])
#    return model

timesteps_ = time_steps - 1
inputs = Input(shape=(timesteps_, ))
tgt1 = tf.keras.layers.Reshape((timesteps_, 1), input_shape=(timesteps_, ))(inputs)

#tgt1 = Dense(units=32, input_shape=(timesteps_, 1))(tgt1)
#1st CNN Layer
tgt2 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(tgt1)
tgt3 = MaxPooling1D(pool_size=2,padding='valid')(tgt2)
#2nd CNN Layer
tgt4 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(tgt3)
tgt5 = MaxPooling1D(pool_size=2, padding='valid')(tgt4)

#tgt6 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(tgt5)
#tgt7 = MaxPooling1D(pool_size=2, padding='valid')(tgt6)
#1st LSTM Layer
#tgt6 = LSTM(32,return_sequences=True)(tgt5) #32
#tgt6_2 = LSTM(30,return_sequences=True)(tgt6) #32
#tgt6_3 = LSTM(22,return_sequences=True)(tgt6_2) #32
#tgt7 = LSTM(16,return_sequences=False)(tgt6) #16
#Dense
tgt6 = Flatten()(tgt5)
#tgt8 = Flatten()(tgt7)
#tgt7 = Dense(32, activation="relu", kernel_initializer="uniform")(tgt6)
predictions = Dense(1, activation="relu", kernel_initializer="uniform")(tgt6)

model = Model(inputs=inputs, outputs=predictions)
model.compile(loss='mae',optimizer='Adam',metrics=['mse','mae'])

# %%
#model = build_model([9,1,1]) #[x_train shape的第二個數字, x_train shape的第三個數字, 1]
#Summary of the Model
print(model.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64)]              0
# _________________________________________________________________
# reshape (Reshape)            (None, 64, 1)             0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 64, 32)            352
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 32, 32)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 32, 32)            10272
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 16, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 513
# =================================================================
# Total params: 11,137
# Trainable params: 11,137
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from timeit import default_timer as timer
start = timer()
history = model.fit(x_train,
                    y_train,
                    batch_size=64,
                    epochs=60,
                    validation_split=0.2,
                    verbose=2)
end = timer()
print(end - start)
# Out:
# Epoch 1/200
# 134/134 - 0s - loss: 0.0191 - mse: 0.0023 - mae: 0.0191 - val_loss: 0.0174 - val_mse: 0.0018 - val_mae: 0.0174
# Epoch 2/200
# 134/134 - 0s - loss: 0.0179 - mse: 0.0022 - mae: 0.0179 - val_loss: 0.0166 - val_mse: 0.0017 - val_mae: 0.0166
# Epoch 3/200
# 134/134 - 0s - loss: 0.0173 - mse: 0.0022 - mae: 0.0173 - val_loss: 0.0164 - val_mse: 0.0017 - val_mae: 0.0164
# Epoch 4/200
# 134/134 - 0s - loss: 0.0172 - mse: 0.0022 - mae: 0.0172 - val_loss: 0.0164 - val_mse: 0.0017 - val_mae: 0.0164
# Epoch 5/200
# 134/134 - 0s - loss: 0.0170 - mse: 0.0022 - mae: 0.0170 - val_loss: 0.0162 - val_mse: 0.0017 - val_mae: 0.0162
# Epoch 6/200
# 134/134 - 0s - loss: 0.0170 - mse: 0.0022 - mae: 0.0170 - val_loss: 0.0162 - val_mse: 0.0017 - val_mae: 0.0162
# Epoch 7/200
# 134/134 - 0s - loss: 0.0169 - mse: 0.0022 - mae: 0.0169 - val_loss: 0.0162 - val_mse: 0.0017 - val_mae: 0.0162
# Epoch 8/200
# 134/134 - 0s - loss: 0.0169 - mse: 0.0022 - mae: 0.0169 - val_loss: 0.0161 - val_mse: 0.0017 - val_mae: 0.0161
# Epoch 9/200
# 134/134 - 0s - loss: 0.0168 - mse: 0.0022 - mae: 0.0168 - val_loss: 0.0161 - val_mse: 0.0016 - val_mae: 0.0161
# Epoch 10/200
# 134/134 - 0s - loss: 0.0167 - mse: 0.0022 - mae: 0.0167 - val_loss: 0.0161 - val_mse: 0.0017 - val_mae: 0.0161
# Epoch 48/200
# 134/134 - 3s - loss: 0.0150 - mse: 0.0018 - mae: 0.0150 - val_loss: 0.0169 - val_mse: 0.0017 - val_mae: 0.0169
# Epoch 49/200
# 134/134 - 3s - loss: 0.0149 - mse: 0.0017 - mae: 0.0149 - val_loss: 0.0168 - val_mse: 0.0016 - val_mae: 0.0168
# Epoch 50/200
# 134/134 - 3s - loss: 0.0148 - mse: 0.0017 - mae: 0.0148 - val_loss: 0.0170 - val_mse: 0.0016 - val_mae: 0.0170
# Epoch 51/200
# 134/134 - 3s - loss: 0.0148 - mse: 0.0017 - mae: 0.0148 - val_loss: 0.0169 - val_mse: 0.0017 - val_mae: 0.0169
# Epoch 52/200
# 134/134 - 3s - loss: 0.0148 - mse: 0.0017 - mae: 0.0148 - val_loss: 0.0169 - val_mse: 0.0017 - val_mae: 0.0169
# Epoch 53/200
# 134/134 - 3s - loss: 0.0148 - mse: 0.0018 - mae: 0.0148 - val_loss: 0.0171 - val_mse: 0.0017 - val_mae: 0.0171
# Epoch 54/200
# 134/134 - 3s - loss: 0.0146 - mse: 0.0017 - mae: 0.0146 - val_loss: 0.0170 - val_mse: 0.0017 - val_mae: 0.0170
# Epoch 55/200
# 134/134 - 3s - loss: 0.0147 - mse: 0.0017 - mae: 0.0147 - val_loss: 0.0171 - val_mse: 0.0017 - val_mae: 0.0171
# Epoch 56/200
# 134/134 - 3s - loss: 0.0146 - mse: 0.0017 - mae: 0.0146 - val_loss: 0.0167 - val_mse: 0.0016 - val_mae: 0.0167
# Epoch 57/200
# 134/134 - 3s - loss: 0.0145 - mse: 0.0017 - mae: 0.0145 - val_loss: 0.0169 - val_mse: 0.0017 - val_mae: 0.0169
# Epoch 58/200
# 134/134 - 3s - loss: 0.0145 - mse: 0.0017 - mae: 0.0145 - val_loss: 0.0171 - val_mse: 0.0017 - val_mae: 0.0171
# Epoch 59/200
# 134/134 - 3s - loss: 0.0145 - mse: 0.0017 - mae: 0.0145 - val_loss: 0.0170 - val_mse: 0.0017 - val_mae: 0.0170
# Epoch 60/200
# 134/134 - 3s - loss: 0.0144 - mse: 0.0017 - mae: 0.0144 - val_loss: 0.0170 - val_mse: 0.0016 - val_mae: 0.0170
# Epoch 61/200
# 134/134 - 3s - loss: 0.0146 - mse: 0.0017 - mae: 0.0146 - val_loss: 0.0172 - val_mse: 0.0017 - val_mae: 0.0172
# Epoch 62/200
# 134/134 - 3s - loss: 0.0144 - mse: 0.0017 - mae: 0.0144 - val_loss: 0.0172 - val_mse: 0.0017 - val_mae: 0.0172
# Epoch 63/200
# 134/134 - 3s - loss: 0.0144 - mse: 0.0017 - mae: 0.0144 - val_loss: 0.0171 - val_mse: 0.0017 - val_mae: 0.0171
# Epoch 64/200
# 134/134 - 3s - loss: 0.0143 - mse: 0.0017 - mae: 0.0143 - val_loss: 0.0173 - val_mse: 0.0017 - val_mae: 0.0173
# Epoch 65/200
# 134/134 - 1s - loss: 0.0143 - mse: 0.0017 - mae: 0.0143 - val_loss: 0.0171 - val_mse: 0.0017 - val_mae: 0.0171
# Epoch 66/200
# 134/134 - 0s - loss: 0.0143 - mse: 0.0017 - mae: 0.0143 - val_loss: 0.0169 - val_mse: 0.0017 - val_mae: 0.0169
# Epoch 67/200
# 134/134 - 0s - loss: 0.0143 - mse: 0.0017 - mae: 0.0143 - val_loss: 0.0171 - val_mse: 0.0017 - val_mae: 0.0171
# Epoch 68/200
# 134/134 - 0s - loss: 0.0142 - mse: 0.0017 - mae: 0.0142 - val_loss: 0.0173 - val_mse: 0.0017 - val_mae: 0.0173
# Epoch 69/200
# 134/134 - 0s - loss: 0.0141 - mse: 0.0017 - mae: 0.0141 - val_loss: 0.0175 - val_mse: 0.0017 - val_mae: 0.0175
# Epoch 70/200
# 134/134 - 0s - loss: 0.0142 - mse: 0.0017 - mae: 0.0142 - val_loss: 0.0172 - val_mse: 0.0017 - val_mae: 0.0172
# Epoch 71/200
# 134/134 - 0s - loss: 0.0141 - mse: 0.0017 - mae: 0.0141 - val_loss: 0.0173 - val_mse: 0.0017 - val_mae: 0.0173
# Epoch 72/200
# 134/134 - 0s - loss: 0.0140 - mse: 0.0017 - mae: 0.0140 - val_loss: 0.0173 - val_mse: 0.0017 - val_mae: 0.0173
# Epoch 73/200
# 134/134 - 0s - loss: 0.0141 - mse: 0.0016 - mae: 0.0141 - val_loss: 0.0172 - val_mse: 0.0017 - val_mae: 0.0172
# Epoch 74/200
# 134/134 - 0s - loss: 0.0140 - mse: 0.0016 - mae: 0.0140 - val_loss: 0.0175 - val_mse: 0.0016 - val_mae: 0.0175
# Epoch 75/200
# 134/134 - 0s - loss: 0.0139 - mse: 0.0016 - mae: 0.0139 - val_loss: 0.0173 - val_mse: 0.0017 - val_mae: 0.0173
# Epoch 76/200
# 134/134 - 0s - loss: 0.0140 - mse: 0.0016 - mae: 0.0140 - val_loss: 0.0172 - val_mse: 0.0017 - val_mae: 0.0172
# Epoch 77/200
# 134/134 - 0s - loss: 0.0140 - mse: 0.0016 - mae: 0.0140 - val_loss: 0.0172 - val_mse: 0.0017 - val_mae: 0.0172
# Epoch 78/200
# 134/134 - 0s - loss: 0.0139 - mse: 0.0016 - mae: 0.0139 - val_loss: 0.0174 - val_mse: 0.0017 - val_mae: 0.0174
# Epoch 79/200
# 134/134 - 0s - loss: 0.0140 - mse: 0.0016 - mae: 0.0140 - val_loss: 0.0176 - val_mse: 0.0017 - val_mae: 0.0176
# Epoch 80/200
# 134/134 - 0s - loss: 0.0139 - mse: 0.0016 - mae: 0.0139 - val_loss: 0.0172 - val_mse: 0.0017 - val_mae: 0.0172
# Epoch 81/200
# 134/134 - 0s - loss: 0.0139 - mse: 0.0016 - mae: 0.0139 - val_loss: 0.0174 - val_mse: 0.0017 - val_mae: 0.0174
# Epoch 82/200
# 134/134 - 0s - loss: 0.0138 - mse: 0.0016 - mae: 0.0138 - val_loss: 0.0173 - val_mse: 0.0017 - val_mae: 0.0173
# Epoch 83/200
# 134/134 - 0s - loss: 0.0138 - mse: 0.0016 - mae: 0.0138 - val_loss: 0.0174 - val_mse: 0.0017 - val_mae: 0.0174
# Epoch 84/200
# 134/134 - 0s - loss: 0.0138 - mse: 0.0016 - mae: 0.0138 - val_loss: 0.0174 - val_mse: 0.0017 - val_mae: 0.0174
# Epoch 85/200
# 134/134 - 0s - loss: 0.0137 - mse: 0.0016 - mae: 0.0137 - val_loss: 0.0173 - val_mse: 0.0017 - val_mae: 0.0173
# Epoch 86/200
# 134/134 - 0s - loss: 0.0137 - mse: 0.0016 - mae: 0.0137 - val_loss: 0.0173 - val_mse: 0.0017 - val_mae: 0.0173
# Epoch 87/200
# 134/134 - 0s - loss: 0.0136 - mse: 0.0016 - mae: 0.0136 - val_loss: 0.0174 - val_mse: 0.0017 - val_mae: 0.0174
# Epoch 88/200
# 134/134 - 0s - loss: 0.0136 - mse: 0.0016 - mae: 0.0136 - val_loss: 0.0176 - val_mse: 0.0017 - val_mae: 0.0176
# Epoch 89/200
# 134/134 - 0s - loss: 0.0136 - mse: 0.0016 - mae: 0.0136 - val_loss: 0.0174 - val_mse: 0.0017 - val_mae: 0.0174
# Epoch 90/200
# 134/134 - 0s - loss: 0.0135 - mse: 0.0016 - mae: 0.0135 - val_loss: 0.0172 - val_mse: 0.0017 - val_mae: 0.0172
# Epoch 91/200
# 134/134 - 0s - loss: 0.0135 - mse: 0.0016 - mae: 0.0135 - val_loss: 0.0175 - val_mse: 0.0017 - val_mae: 0.0175
# Epoch 92/200
# 134/134 - 0s - loss: 0.0135 - mse: 0.0016 - mae: 0.0135 - val_loss: 0.0176 - val_mse: 0.0017 - val_mae: 0.0176
# Epoch 93/200
# 134/134 - 0s - loss: 0.0134 - mse: 0.0016 - mae: 0.0134 - val_loss: 0.0177 - val_mse: 0.0017 - val_mae: 0.0177
# Epoch 94/200
# 134/134 - 0s - loss: 0.0134 - mse: 0.0016 - mae: 0.0134 - val_loss: 0.0177 - val_mse: 0.0017 - val_mae: 0.0177
# Epoch 95/200
# 134/134 - 0s - loss: 0.0134 - mse: 0.0016 - mae: 0.0134 - val_loss: 0.0175 - val_mse: 0.0017 - val_mae: 0.0175
# Epoch 96/200
# 134/134 - 0s - loss: 0.0134 - mse: 0.0016 - mae: 0.0134 - val_loss: 0.0175 - val_mse: 0.0017 - val_mae: 0.0175
# Epoch 97/200
# 134/134 - 0s - loss: 0.0133 - mse: 0.0016 - mae: 0.0133 - val_loss: 0.0178 - val_mse: 0.0017 - val_mae: 0.0178
# Epoch 98/200
# 134/134 - 0s - loss: 0.0134 - mse: 0.0016 - mae: 0.0134 - val_loss: 0.0178 - val_mse: 0.0017 - val_mae: 0.0178
# Epoch 99/200
# 134/134 - 0s - loss: 0.0133 - mse: 0.0016 - mae: 0.0133 - val_loss: 0.0176 - val_mse: 0.0017 - val_mae: 0.0176
# Epoch 100/200
# 134/134 - 0s - loss: 0.0134 - mse: 0.0016 - mae: 0.0134 - val_loss: 0.0176 - val_mse: 0.0017 - val_mae: 0.0176
# Epoch 101/200
# 134/134 - 0s - loss: 0.0133 - mse: 0.0016 - mae: 0.0133 - val_loss: 0.0176 - val_mse: 0.0017 - val_mae: 0.0176
# Epoch 102/200
# 134/134 - 0s - loss: 0.0132 - mse: 0.0015 - mae: 0.0132 - val_loss: 0.0176 - val_mse: 0.0017 - val_mae: 0.0176
# Epoch 103/200
# Epoch 122/200
# 134/134 - 0s - loss: 0.0127 - mse: 0.0015 - mae: 0.0127 - val_loss: 0.0182 - val_mse: 0.0017 - val_mae: 0.0182
# Epoch 123/200
# 134/134 - 0s - loss: 0.0128 - mse: 0.0015 - mae: 0.0128 - val_loss: 0.0181 - val_mse: 0.0017 - val_mae: 0.0181
# Epoch 124/200
# 134/134 - 0s - loss: 0.0127 - mse: 0.0015 - mae: 0.0127 - val_loss: 0.0182 - val_mse: 0.0017 - val_mae: 0.0182
# Epoch 125/200
# 134/134 - 0s - loss: 0.0127 - mse: 0.0015 - mae: 0.0127 - val_loss: 0.0180 - val_mse: 0.0017 - val_mae: 0.0180
# Epoch 126/200
# 134/134 - 0s - loss: 0.0126 - mse: 0.0015 - mae: 0.0126 - val_loss: 0.0181 - val_mse: 0.0017 - val_mae: 0.0181
# Epoch 127/200
# 134/134 - 0s - loss: 0.0127 - mse: 0.0015 - mae: 0.0127 - val_loss: 0.0182 - val_mse: 0.0017 - val_mae: 0.0182
# Epoch 128/200
# 134/134 - 0s - loss: 0.0126 - mse: 0.0015 - mae: 0.0126 - val_loss: 0.0180 - val_mse: 0.0017 - val_mae: 0.0180
# Epoch 129/200
# 134/134 - 0s - loss: 0.0127 - mse: 0.0015 - mae: 0.0127 - val_loss: 0.0186 - val_mse: 0.0017 - val_mae: 0.0186
# Epoch 130/200
# 134/134 - 0s - loss: 0.0127 - mse: 0.0015 - mae: 0.0127 - val_loss: 0.0183 - val_mse: 0.0018 - val_mae: 0.0183
# Epoch 131/200
# 134/134 - 0s - loss: 0.0126 - mse: 0.0015 - mae: 0.0126 - val_loss: 0.0180 - val_mse: 0.0017 - val_mae: 0.0180
# Epoch 132/200
# 134/134 - 0s - loss: 0.0126 - mse: 0.0015 - mae: 0.0126 - val_loss: 0.0183 - val_mse: 0.0017 - val_mae: 0.0183
# Epoch 133/200
# 134/134 - 0s - loss: 0.0125 - mse: 0.0014 - mae: 0.0125 - val_loss: 0.0183 - val_mse: 0.0017 - val_mae: 0.0183
# Epoch 134/200
# 134/134 - 0s - loss: 0.0124 - mse: 0.0014 - mae: 0.0124 - val_loss: 0.0184 - val_mse: 0.0017 - val_mae: 0.0184
# Epoch 135/200
# 134/134 - 0s - loss: 0.0125 - mse: 0.0015 - mae: 0.0125 - val_loss: 0.0180 - val_mse: 0.0017 - val_mae: 0.0180
# Epoch 136/200
# 134/134 - 0s - loss: 0.0125 - mse: 0.0015 - mae: 0.0125 - val_loss: 0.0181 - val_mse: 0.0017 - val_mae: 0.0181
# Epoch 137/200
# 134/134 - 0s - loss: 0.0125 - mse: 0.0015 - mae: 0.0125 - val_loss: 0.0181 - val_mse: 0.0017 - val_mae: 0.0181
# Epoch 138/200
# 134/134 - 0s - loss: 0.0125 - mse: 0.0014 - mae: 0.0125 - val_loss: 0.0179 - val_mse: 0.0017 - val_mae: 0.0179
# Epoch 139/200
# 134/134 - 0s - loss: 0.0124 - mse: 0.0014 - mae: 0.0124 - val_loss: 0.0182 - val_mse: 0.0017 - val_mae: 0.0182
# Epoch 140/200
# Epoch 196/200
# 134/134 - 0s - loss: 0.0115 - mse: 0.0013 - mae: 0.0115 - val_loss: 0.0188 - val_mse: 0.0019 - val_mae: 0.0188
# Epoch 197/200
# 134/134 - 0s - loss: 0.0116 - mse: 0.0013 - mae: 0.0116 - val_loss: 0.0193 - val_mse: 0.0019 - val_mae: 0.0193
# Epoch 198/200
# 134/134 - 0s - loss: 0.0115 - mse: 0.0013 - mae: 0.0115 - val_loss: 0.0194 - val_mse: 0.0019 - val_mae: 0.0194
# Epoch 199/200
# 134/134 - 0s - loss: 0.0116 - mse: 0.0013 - mae: 0.0116 - val_loss: 0.0193 - val_mse: 0.0019 - val_mae: 0.0193
# Epoch 200/200
# 134/134 - 0s - loss: 0.0117 - mse: 0.0013 - mae: 0.0117 - val_loss: 0.0194 - val_mse: 0.0019 - val_mae: 0.0194
# 141.1098917

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'mse', 'mae', 'val_loss', 'val_mse', 'val_mae'])

# %%
# 画出训练集和验证集的损失曲线

import matplotlib.pyplot as plt

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
loss_values50 = loss_values[0:150]
val_loss_values50 = val_loss_values[0:150]
epochs = range(1, len(loss_values50) + 1)
plt.plot(epochs, loss_values50, 'b',color = 'blue', label='Training loss')
plt.plot(epochs, val_loss_values50, 'b',color='orange', label='Validation loss')
plt.rc('font', size = 18)
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.xticks(epochs)
fig = plt.gcf()
fig.set_size_inches(15,7)
#fig.savefig('img/tcstest&validationlosscnn.png', dpi=300)
plt.show()

# %%
# 画出训练集和验证集的误差图像

#mae = history_dict['mean_absolute_error']
#vmae = history_dict['val_mean_absolute_error']
mae = history.history['mae']
vmae = history.history['val_mae']
epochs = range(1, len(mae) + 1)
plt.plot(epochs, mae, 'b',color = 'blue', label='Training error')
plt.plot(epochs, vmae, 'b',color='orange', label='Validation error')
plt.title('Training and validation error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.legend()
plt.xticks(epochs)
fig = plt.gcf()
fig.set_size_inches(15,7)
#fig.savefig('img/tcstest&validationerrorcnn.png', dpi=300)
plt.show()

# %%
model.metrics_names
# Out:
# ['loss', 'mse', 'mae']

# %%
trainScore = model.evaluate(x_train, y_train, verbose=0)
testScore = model.evaluate(x_test, y_test, verbose=0)

# %%
#predicting values for y_test
p = model.predict(x_test)

# %%
plt.plot(y_test, label='y_test')
plt.plot(p, label='prediction')
plt.xlabel('Test Data Ai')
plt.ylabel('predict Ai')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(15, 5)
#fig.savefig('img/tcstestcnn.png', dpi=300)
plt.show()

# %%
p1= model.predict(x_train)

# %%
plt.plot(y_train, label='y_train')
x = np.array(range(8534,10668)) #range(x_train shape第一個數字的0.8倍, x_train shape第一個數字)
plt.plot(x,p1[8534:],color = 'magenta',label ='prediction on validating samples') #p1[數字:] 數字代表x_train shape第一個數字的0.8倍
plt.plot(p1[:8534],color='red', label='prediction on training samples')
#x = np.array(range(29512,36890)) #range(x_train shape第一個數字的0.8倍, x_train shape第一個數字)
#plt.plot(x,p1[29512:],color = 'magenta',label ='prediction on validating samples')
#plt.plot(y_train,color='blue', label='y_train')
plt.xlabel('No. of Trading Days')
plt.ylabel('Close Value (scaled)')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(20,10)
#fig.savefig('img/tcstraincnn.png', dpi=300)
plt.show()

# %%
#手動正規化
y = y_test * maxAi   # 原始数据经过除以10000进行缩放，因此乘以10000,返回到原始数据规模
y_pred = p.reshape(2667)   # 测试集数据大小为265
y_pred = y_pred * maxAi   # 原始数据经过除以10000进行缩放，因此乘以10000,返回到原始数据规模

# %%
from sklearn.metrics import mean_absolute_error

# %%
print('Trainscore RMSE \tTrain Mean abs Error \tTestscore Rmse \t Test Mean abs Error')
print('%.9f \t\t %.9f \t\t %.9f \t\t %.9f' % (math.sqrt(trainScore[0]),trainScore[1],math.sqrt(testScore[0]),testScore[1]))
# Out:
# Trainscore RMSE 	Train Mean abs Error 	Testscore Rmse 	 Test Mean abs Error
# 0.114347166 		 0.001361004 		 0.130378973 		 0.001436707

# %%
print('mean absolute error \t mean absolute percentage error')
print(' %.9f \t\t\t %.9f' % (mean_absolute_error(y,y_pred),(np.mean(np.abs((y - y_pred) / y)) * 100)))
# Out:
# mean absolute error 	 mean absolute percentage error
#  7206.132526888 			 nan
# C:\Users\joker\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# C:\Users\joker\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %%
Ytrain = y_train * maxAi
Ytest = y_test * maxAi

P1 = p1 * maxAi
PP = p * maxAi

# %%
Y = np.concatenate((Ytrain,Ytest),axis = 0)
plt.plot(Y, label='Y')
P = np.concatenate((P1,PP),axis = 0)
#plotting the complete Y set with predicted values on x_train and x_test(variable p1 & p respectively given above)
#for 
plt.plot(P[:8534],color='red', label='prediction on training samples') #p[:數字] 數字代表x_train shape第一個數字的0.8倍
#for validating samples
z = np.array(range(8534,10668)) #range(x_train shape第一個數字的0.8倍, x_train shape第一個數字)
plt.plot(z,P[8534:10668],color = 'orange',label ='prediction on validating samples') #P[x_train shape第一個數字的0.8倍:x_train shape第一個數字]
#for testing samples
x = np.array(range(10668,13335)) #range(x_train shape第一個數字, x_train shape第一個數字 + x_test shape第一個數字)
plt.plot(x,P[10668:],color = 'purple',label ='prediction on testing samples(x_test)') #p[數字:] 數字代表x_train shape第一個數字

#plt.plot(Y,color='blue', label='Y')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(20,12)
plt.show()

# %%
plt.plot(Ytest[500:1000], label='y_test')
plt.plot(PP[500:1000], label='prediction')
plt.title('ONU16 request')
plt.xlabel('Test Case')
plt.ylabel('Ai')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(15, 10)
#fig.savefig('img/tcstestcnn.png', dpi=300)
plt.legend()
plt.show()

# %%
print('timesteps : ',timesteps_)
plt.plot(history.history['mae'])
plt.title('mae')
# Out:
# timesteps :  64
# Text(0.5, 1.0, 'mae')

# %%
print('timesteps : ',timesteps_)
plt.plot(history.history['mse'])
plt.title('mse')
# Out:
# timesteps :  64
# Text(0.5, 1.0, 'mse')

# %%
plt.title('loss')
plt.plot(history.history['loss'])

# %%
#model.save('./SelfData_thesis/0704_U08D00_CNN_ONU16_AipredictAi_423923_2layer_timesteps64_Epoch60.h5', include_optimizer=False)
