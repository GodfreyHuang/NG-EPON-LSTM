# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, LSTM, Reshape, Dropout, LayerNormalization
from tensorflow.keras.models import Model, Sequential
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import math
from sklearn.metrics import mean_absolute_error as mae
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import concatenate
sc = MinMaxScaler(feature_range = (0,1))

import pandas as pd

# %%
df1 = pd.read_csv('AI_U16_ONU16_15S_Gi-1.csv', usecols=[0], engine='python')
df1.head()
# Out:
#     Gi-1
# 0  56923
# 1  58620
# 2  60624
# 3  43173
# 4  39962

# %%
df2 = pd.read_csv('AI_U16_ONU16_15S_Ai.csv', usecols=[0], engine='python')
df2.head()
# Out:
#       Ai
# 0  58620
# 1  60624
# 2  43173
# 3  39962
# 4  71209

# %%
df1 = df1.values
df1 = df1.astype('float32')

df2 = df2.values
df2 = df2.astype('float32')

# %%
#df2 = []

#for i in range(len(df)):
#    if(df[i] > 195000.0):
#        df[i] = 195000.0
#    df2.append(df[i])

# %%
#df = df2
df1 = df1[:1000]
df2 = df2[:1000]
print(len(df1))
print(len(df2))
# Out:
# 1000
# 1000

# %%
# normalize the dataset
#scaler = MinMaxScaler(feature_range=(0, 1))
#datasetG = scaler.fit_transform(df1)
#datasetA = scaler.fit_transform(df2)
datasetG = df1
datasetA = df2

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
# split into train and test sets
train_sizeG = int(len(datasetG) * 0.7) 
test_sizeG = len(datasetG) - train_sizeG
trainG, testG = datasetG[0:train_sizeG], datasetG[train_sizeG:len(datasetG)]

trainG = scaler.fit_transform(trainG)
testG = scaler.fit_transform(testG)
print(len(trainG), len(testG))
# Out:
# 700 300

# %%
# split into train and test sets
train_sizeA = int(len(datasetA) * 0.7) 
test_sizeA = len(datasetA) - train_sizeA
trainA, testA = datasetA[0:train_sizeA], datasetA[train_sizeA:len(datasetA)]

#scaler = MinMaxScaler(feature_range=(0, 1))
trainA = scaler.fit_transform(trainA)
testA = scaler.fit_transform(testA)
print(len(trainA), len(testA))
# Out:
# 700 300

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 10 #16
trainX_G, trainY_G = create_dataset(trainG, look_back)
testX_G, testY_G = create_dataset(testG, look_back)

trainX_A, trainY_A = create_dataset(trainA, look_back)
testX_A, testY_A = create_dataset(testA, look_back)

# %%
# reshape input to be [samples, time steps, features]
trainX_G = np.reshape(trainX_G, (trainX_G.shape[0], look_back, 1))
testX_G = np.reshape(testX_G, (testX_G.shape[0], look_back, 1))

trainX_A = np.reshape(trainX_A, (trainX_A.shape[0], look_back, 1))
testX_A = np.reshape(testX_A, (testX_A.shape[0], look_back, 1))
#print(trainX.shape[1])
print(trainX_G.shape)
print(trainY_G.shape)
print(testX_G.shape)
print(testY_G.shape)

print(trainX_A.shape)
print(trainY_A.shape)
print(testX_A.shape)
print(testY_A.shape)
# Out:
# (689, 10, 1)
# (689, 1)
# (289, 10, 1)
# (289, 1)
# (689, 10, 1)
# (689, 1)
# (289, 10, 1)
# (289, 1)

# %%
#inputsR = Input(shape=(timesteps,))
inputs_A = Input(shape=(look_back,))
inputs_G = Input(shape=(look_back,))
#inputs = LayerNormalization(axis=1)(inputs)
#inputs_R_test = Reshape((inputs_R.shape[1],1))(inputs_R)
inputs_A_test = Reshape((inputs_A.shape[1], 1))(inputs_A)
inputs_G_test = Reshape((inputs_G.shape[1], 1))(inputs_G)

input_merge = concatenate([inputs_A_test,inputs_G_test], axis = -1)

tgt1 = Reshape((look_back, 2))(input_merge)

#tf.print(tgt1, output_stream=sys.stderr)

# %%
#tgt1 = LSTM(units=40, input_shape=(look_back, 2))(tgt1)
#predictions = Dense(1, activation='relu')(tgt1)

tgt1 = LSTM(units=40, return_sequences = True, input_shape=(look_back, 2))(tgt1)
tgt1 = Dropout(0.2)(tgt1)

tgt2 = LSTM(units=40, return_sequences = True)(tgt1)
tgt2 = Dropout(0.2)(tgt2)

tgt3 = LSTM(units=40, return_sequences = True)(tgt2)
tgt3 = Dropout(0.2)(tgt3)

tgt4 = LSTM(units=40, return_sequences = True)(tgt3)
tgt4 = Dropout(0.2)(tgt4)

tgt5 = LSTM(units=40, return_sequences = True)(tgt4)
tgt5 = Dropout(0.2)(tgt5)

tgt6 = LSTM(units=40, return_sequences = True)(tgt5)
tgt6 = Dropout(0.2)(tgt6)

tgt7 = LSTM(units=40)(tgt6)
tgt7 = Dropout(0.2)(tgt7)

#tgt8 = LSTM(units=40)(tgt7)
#tgt8 = Dropout(0.2)(tgt8)

#tgt9 = LSTM(units=20, return_sequences = True)(tgt8)
#tgt9 = Dropout(0.2)(tgt9)

#tgt4 = LSTM(units=40)(tgt3)
#tgt4 = Dropout(0.2)(tgt4)

#tgt6 = LSTM(units=40, return_sequences = True)(tgt5)

#tgt7 = LSTM(units=40)(tgt6)


#tgt5 = Flatten()(tgt5)
#predictions = Dense(1, activation='relu')(tgt4)
predictions = Dense(1)(tgt7)


model = Model(inputs=[inputs_A, inputs_G], outputs=predictions)
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mse','mae'])

history = model.fit([trainX_A, trainX_G], trainY_A, epochs=200, batch_size=32) #[1,0,0], [0,0,1]
# Out:
# Epoch 1/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0382
# Epoch 2/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0366
# Epoch 3/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0373
# Epoch 4/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0362
# Epoch 5/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0352
# Epoch 6/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0359
# Epoch 7/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0353
# Epoch 8/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0351
# Epoch 9/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0352
# Epoch 10/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0339
# Epoch 11/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0364
# Epoch 12/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0345
# Epoch 13/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0340
# Epoch 14/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0353
# Epoch 15/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0345
# Epoch 16/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0356
# Epoch 17/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0350
# Epoch 18/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0336
# Epoch 19/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0346
# Epoch 20/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0350
# Epoch 21/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0340
# Epoch 22/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0336
# Epoch 23/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0354
# Epoch 24/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0360
# Epoch 25/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0353
# Epoch 26/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0349
# Epoch 27/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0345
# Epoch 28/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0343
# Epoch 29/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0341
# Epoch 30/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0343
# Epoch 31/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0342
# Epoch 32/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0344
# Epoch 33/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0359
# Epoch 34/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0349
# Epoch 35/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0340
# Epoch 36/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0325
# Epoch 37/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0325
# Epoch 38/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0344
# Epoch 39/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0338
# Epoch 40/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0331
# Epoch 41/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0321
# Epoch 42/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0325
# Epoch 43/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0325
# Epoch 44/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0328
# Epoch 45/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0332
# Epoch 46/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0326
# Epoch 47/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0340
# Epoch 48/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0318
# Epoch 49/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0317
# Epoch 50/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0310
# Epoch 51/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0314
# Epoch 52/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0308
# Epoch 53/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0331
# Epoch 54/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0316
# Epoch 55/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0324
# Epoch 56/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0315
# Epoch 57/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0315
# Epoch 58/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0319
# Epoch 59/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0311
# Epoch 60/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0319
# Epoch 61/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0316
# Epoch 62/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0319
# Epoch 63/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0309
# Epoch 64/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0311
# Epoch 65/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0306
# Epoch 66/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0310
# Epoch 67/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0309
# Epoch 68/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0306
# Epoch 69/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0311
# Epoch 70/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0307
# Epoch 71/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0316
# Epoch 72/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0305
# Epoch 73/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0323
# Epoch 74/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0332
# Epoch 75/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0314
# Epoch 76/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0305
# Epoch 77/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0304
# Epoch 78/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0307
# Epoch 79/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0303
# Epoch 80/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0310
# Epoch 81/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0311
# Epoch 82/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0307
# Epoch 83/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0307
# Epoch 84/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0299
# Epoch 85/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0303
# Epoch 86/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0314
# Epoch 87/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0311
# Epoch 88/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0306
# Epoch 89/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0313
# Epoch 90/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0308
# Epoch 91/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0316
# Epoch 92/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0310
# Epoch 93/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0311
# Epoch 94/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0304
# Epoch 95/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0288
# Epoch 96/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0308
# Epoch 97/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0302
# Epoch 98/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0304
# Epoch 99/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0290
# Epoch 100/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0297
# Epoch 101/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0295
# Epoch 102/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0290
# Epoch 103/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0296
# Epoch 104/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0293
# Epoch 105/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0291
# Epoch 106/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0293
# Epoch 107/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0286
# Epoch 108/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0294
# Epoch 109/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0302
# Epoch 110/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0294: 0s - loss: 0.0016 - mse: 0.0016 - mae: 0
# Epoch 111/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0292
# Epoch 112/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0295
# Epoch 113/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0293
# Epoch 114/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0292
# Epoch 115/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0298
# Epoch 116/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0283
# Epoch 117/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0295
# Epoch 118/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0288
# Epoch 119/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0283
# Epoch 120/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0293
# Epoch 121/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0301
# Epoch 122/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0292
# Epoch 123/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0287
# Epoch 124/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0292
# Epoch 125/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0292
# Epoch 126/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0288
# Epoch 127/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0293
# Epoch 128/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0301
# Epoch 129/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0290
# Epoch 130/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0289
# Epoch 131/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0284
# Epoch 132/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0293
# Epoch 133/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0284
# Epoch 134/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0323
# Epoch 135/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0302
# Epoch 136/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0300
# Epoch 137/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0300
# Epoch 138/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0291
# Epoch 139/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0297
# Epoch 140/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0295
# Epoch 141/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0290
# Epoch 142/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0304
# Epoch 143/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0306
# Epoch 144/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0294
# Epoch 145/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0291
# Epoch 146/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0292
# Epoch 147/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0281
# Epoch 148/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0287
# Epoch 149/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0287
# Epoch 150/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0292
# Epoch 151/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0281
# Epoch 152/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0286
# Epoch 153/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0280
# Epoch 154/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0282
# Epoch 155/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0292
# Epoch 156/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0283
# Epoch 157/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0285
# Epoch 158/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0298
# Epoch 159/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0277
# Epoch 160/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0286
# Epoch 161/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0292
# Epoch 162/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0279
# Epoch 163/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0290
# Epoch 164/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0285
# Epoch 165/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0312
# Epoch 166/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0311
# Epoch 167/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0290
# Epoch 168/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0291
# Epoch 169/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0289
# Epoch 170/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0296
# Epoch 171/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0290
# Epoch 172/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0288
# Epoch 173/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0271
# Epoch 174/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0284
# Epoch 175/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0277
# Epoch 176/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0279
# Epoch 177/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0282
# Epoch 178/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0277
# Epoch 179/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0286
# Epoch 180/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0280
# Epoch 181/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0284
# Epoch 182/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0285
# Epoch 183/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0283
# Epoch 184/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0282
# Epoch 185/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0295
# Epoch 186/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0304
# Epoch 187/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0318
# Epoch 188/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0327
# Epoch 189/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0328
# Epoch 190/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0331
# Epoch 191/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0328
# Epoch 192/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0344
# Epoch 193/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0353
# Epoch 194/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0326
# Epoch 195/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0321
# Epoch 196/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0318
# Epoch 197/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0312
# Epoch 198/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0293
# Epoch 199/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0298
# Epoch 200/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0288

# %% [markdown]
# look back = timesteps = 10, 1 LSTM layers

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mae'])
plt.title('mae')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mae')

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mse'])
plt.title('mse')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mse')

# %%
plt.title('loss')
plt.plot(history.history['loss'])

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 10, 1)        0           input_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 10, 1)        0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 2)        0           reshape[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 10, 2)        0           concatenate[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 40)           6880        reshape_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 40)           0           lstm[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            41          dropout[0][0]
# ==================================================================================================
# Total params: 6,921
# Trainable params: 6,921
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.metrics import mean_squared_error as mse

trainPredict = model.predict([trainX_A, trainX_G])
testPredict = model.predict([testX_A, testX_G])

# invert predictions
#scaler = MinMaxScaler(feature_range=(0, 1))
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY_A)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY_A)
# calculate root mean squared error
trainScore = math.sqrt(mse(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mse(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# calculate root mean absolute error
trainScore2 = math.sqrt(mae(trainY, trainPredict))
print('Train Score: %.2f RMAE' % (trainScore2))
testScore2 = math.sqrt(mae(testY, testPredict))
print('Test Score: %.2f RMAE' % (testScore2))

testPredictPlot = np.empty_like(datasetA)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(datasetA)-1] = testPredict
# plot baseline and predictions
plt.figure(figsize=(15, 10))
#plt.plot(datasetA[1500:])
plt.plot(datasetA[750:])
#plt.plot(trainPredictPlot)
plt.plot(testPredictPlot[750:])
plt.show()
# Out:
# Train Score: 17912.09 RMSE
# Test Score: 49700.58 RMSE
# Train Score: 102.84 RMAE
# Test Score: 178.48 RMAE

# %% [markdown]
# look back = timesteps = 10, 2 LSTM layers

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mae'])
plt.title('mae')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mae')

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mse'])
plt.title('mse')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mse')

# %%
plt.title('loss')
plt.plot(history.history['loss'])

# %%
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 10, 1)        0           input_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 10, 1)        0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 2)        0           reshape[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 10, 2)        0           concatenate[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 10, 40)       6880        reshape_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 10, 40)       0           lstm[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 10, 40)       12960       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 10, 40)       0           lstm_2[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 40)           12960       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 40)           0           lstm_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            41          dropout_3[0][0]
# ==================================================================================================
# Total params: 32,841
# Trainable params: 32,841
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.metrics import mean_squared_error as mse

trainPredict = model.predict([trainX_A, trainX_G])
testPredict = model.predict([testX_A, testX_G])

# invert predictions
#scaler = MinMaxScaler(feature_range=(0, 1))
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY_A)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY_A)
# calculate root mean squared error
trainScore = math.sqrt(mse(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mse(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# calculate root mean absolute error
trainScore2 = math.sqrt(mae(trainY, trainPredict))
print('Train Score: %.2f RMAE' % (trainScore2))
testScore2 = math.sqrt(mae(testY, testPredict))
print('Test Score: %.2f RMAE' % (testScore2))

testPredictPlot = np.empty_like(datasetA)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(datasetA)-1] = testPredict
# plot baseline and predictions
plt.figure(figsize=(15, 10))
#plt.plot(datasetA[1500:])
plt.plot(datasetA[750:])
#plt.plot(trainPredictPlot)
plt.plot(testPredictPlot[750:])
plt.show()
# Out:
# Train Score: 17724.54 RMSE
# Test Score: 56713.64 RMSE
# Train Score: 105.38 RMAE
# Test Score: 186.30 RMAE

# %% [markdown]
# look back = timesteps = 10, 3 LSTM layers

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mae'])
plt.title('mae')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mae')

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mse'])
plt.title('mse')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mse')

# %%
plt.title('loss')
plt.plot(history.history['loss'])

# %%
model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 10, 1)        0           input_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 10, 1)        0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 2)        0           reshape[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 10, 2)        0           concatenate[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 10, 40)       6880        reshape_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 10, 40)       0           lstm[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 10, 40)       12960       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 10, 40)       0           lstm_2[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 10, 40)       12960       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10, 40)       0           lstm_4[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 10, 40)       12960       dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 10, 40)       0           lstm_5[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 40)           12960       dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 40)           0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            41          dropout_6[0][0]
# ==================================================================================================
# Total params: 58,761
# Trainable params: 58,761
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.metrics import mean_squared_error as mse

trainPredict = model.predict([trainX_A, trainX_G])
testPredict = model.predict([testX_A, testX_G])

# invert predictions
#scaler = MinMaxScaler(feature_range=(0, 1))
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY_A)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY_A)
# calculate root mean squared error
trainScore = math.sqrt(mse(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mse(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# calculate root mean absolute error
trainScore2 = math.sqrt(mae(trainY, trainPredict))
print('Train Score: %.2f RMAE' % (trainScore2))
testScore2 = math.sqrt(mae(testY, testPredict))
print('Test Score: %.2f RMAE' % (testScore2))

testPredictPlot = np.empty_like(datasetA)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(datasetA)-1] = testPredict
# plot baseline and predictions
plt.figure(figsize=(15, 10))
#plt.plot(datasetA[1500:])
plt.plot(datasetA[750:])
#plt.plot(trainPredictPlot)
plt.plot(testPredictPlot[750:])
plt.show()
# Out:
# Train Score: 14716.40 RMSE
# Test Score: 62497.84 RMSE
# Train Score: 99.64 RMAE
# Test Score: 193.36 RMAE

# %% [markdown]
# look back = timesteps = 10, 4 LSTM layers

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mae'])
plt.title('mae')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mae')

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mse'])
plt.title('mse')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mse')

# %%
plt.title('loss')
plt.plot(history.history['loss'])

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 10, 1)        0           input_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 10, 1)        0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 2)        0           reshape[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 10, 2)        0           concatenate[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 10, 40)       6880        reshape_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 10, 40)       0           lstm[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 10, 40)       12960       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 10, 40)       0           lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 10, 40)       12960       dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 10, 40)       0           lstm_2[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 40)           12960       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 40)           0           lstm_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            41          dropout_3[0][0]
# ==================================================================================================
# Total params: 45,801
# Trainable params: 45,801
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.metrics import mean_squared_error as mse

trainPredict = model.predict([trainX_A, trainX_G])
testPredict = model.predict([testX_A, testX_G])

# %%
# invert predictions
#scaler = MinMaxScaler(feature_range=(0, 1))
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY_A)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY_A)
# calculate root mean squared error
trainScore = math.sqrt(mse(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mse(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# calculate root mean absolute error
trainScore2 = math.sqrt(mae(trainY, trainPredict))
print('Train Score: %.2f RMAE' % (trainScore2))
testScore2 = math.sqrt(mae(testY, testPredict))
print('Test Score: %.2f RMAE' % (testScore2))
# Out:
# Train Score: 17668.28 RMSE
# Test Score: 55028.20 RMSE
# Train Score: 99.03 RMAE
# Test Score: 188.62 RMAE

# %%
testPredictPlot = np.empty_like(datasetA)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(datasetA)-1] = testPredict
# plot baseline and predictions
plt.figure(figsize=(15, 10))
#plt.plot(datasetA[1500:])
plt.plot(datasetA[750:])
#plt.plot(trainPredictPlot)
plt.plot(testPredictPlot[750:])
plt.show()

# %% [markdown]
# look back = timesteps = 10, 5 LSTM layers

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mae'])
plt.title('mae')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mae')

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mse'])
plt.title('mse')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mse')

# %%
plt.title('loss')
plt.plot(history.history['loss'])

# %%
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 10, 1)        0           input_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 10, 1)        0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 2)        0           reshape[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 10, 2)        0           concatenate[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 10, 40)       6880        reshape_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 10, 40)       0           lstm[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 10, 40)       12960       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10, 40)       0           lstm_4[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 10, 40)       12960       dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 10, 40)       0           lstm_5[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 10, 40)       12960       dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 10, 40)       0           lstm_6[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   (None, 10, 40)       12960       dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 10, 40)       0           lstm_7[0][0]
# __________________________________________________________________________________________________
# lstm_8 (LSTM)                   (None, 40)           12960       dropout_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 40)           0           lstm_8[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            41          dropout_8[0][0]
# ==================================================================================================
# Total params: 71,721
# Trainable params: 71,721
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.metrics import mean_squared_error as mse

trainPredict = model.predict([trainX_A, trainX_G])
testPredict = model.predict([testX_A, testX_G])

# %%
# invert predictions
#scaler = MinMaxScaler(feature_range=(0, 1))
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY_A)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY_A)
# calculate root mean squared error
trainScore = math.sqrt(mse(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mse(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# calculate root mean absolute error
trainScore2 = math.sqrt(mae(trainY, trainPredict))
print('Train Score: %.2f RMAE' % (trainScore2))
testScore2 = math.sqrt(mae(testY, testPredict))
print('Test Score: %.2f RMAE' % (testScore2))
# Out:
# Train Score: 16262.90 RMSE
# Test Score: 70190.27 RMSE
# Train Score: 103.00 RMAE
# Test Score: 203.72 RMAE

# %%
testPredictPlot = np.empty_like(datasetA)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(datasetA)-1] = testPredict
# plot baseline and predictions
plt.figure(figsize=(15, 10))
#plt.plot(datasetA[1500:])
plt.plot(datasetA[750:])
#plt.plot(trainPredictPlot)
plt.plot(testPredictPlot[750:])
plt.show()

# %% [markdown]
# look back = timesteps = 10, 6 LSTM layers

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mae'])
plt.title('mae')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mae')

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mse'])
plt.title('mse')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mse')

# %%
plt.title('loss')
plt.plot(history.history['loss'])

# %%
model.summary()
# Out:
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 10, 1)        0           input_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 10, 1)        0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 2)        0           reshape[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 10, 2)        0           concatenate[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 10, 40)       6880        reshape_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 10, 40)       0           lstm[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 10, 40)       12960       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10, 40)       0           lstm_4[0][0]
# __________________________________________________________________________________________________
# lstm_9 (LSTM)                   (None, 10, 40)       12960       dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 10, 40)       0           lstm_9[0][0]
# __________________________________________________________________________________________________
# lstm_15 (LSTM)                  (None, 10, 40)       12960       dropout_9[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 10, 40)       0           lstm_15[0][0]
# __________________________________________________________________________________________________
# lstm_16 (LSTM)                  (None, 10, 40)       12960       dropout_15[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 10, 40)       0           lstm_16[0][0]
# __________________________________________________________________________________________________
# lstm_17 (LSTM)                  (None, 10, 40)       12960       dropout_16[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 10, 40)       0           lstm_17[0][0]
# __________________________________________________________________________________________________
# lstm_18 (LSTM)                  (None, 10, 40)       12960       dropout_17[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 10, 40)       0           lstm_18[0][0]
# __________________________________________________________________________________________________
# lstm_19 (LSTM)                  (None, 10, 40)       12960       dropout_18[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 10, 40)       0           lstm_19[0][0]
# __________________________________________________________________________________________________
# lstm_20 (LSTM)                  (None, 40)           12960       dropout_19[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 40)           0           lstm_20[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            41          dropout_20[0][0]
# ==================================================================================================
# Total params: 110,601
# Trainable params: 110,601
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.metrics import mean_squared_error as mse

trainPredict = model.predict([trainX_A, trainX_G])
testPredict = model.predict([testX_A, testX_G])

# %%
# invert predictions
#scaler = MinMaxScaler(feature_range=(0, 1))
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY_A)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY_A)
# calculate root mean squared error
trainScore = math.sqrt(mse(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mse(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# calculate root mean absolute error
trainScore2 = math.sqrt(mae(trainY, trainPredict))
print('Train Score: %.2f RMAE' % (trainScore2))
testScore2 = math.sqrt(mae(testY, testPredict))
print('Test Score: %.2f RMAE' % (testScore2))
# Out:
# Train Score: 13911.83 RMSE
# Test Score: 61399.85 RMSE
# Train Score: 98.41 RMAE
# Test Score: 201.64 RMAE

# %%
testPredictPlot = np.empty_like(datasetA)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(datasetA)-1] = testPredict
# plot baseline and predictions
plt.figure(figsize=(15, 10))
#plt.plot(datasetA[1500:])
plt.plot(datasetA[750:])
#plt.plot(trainPredictPlot)
plt.plot(testPredictPlot[750:])
plt.show()

# %% [markdown]
# look back = timesteps = 10, 7 LSTM layers

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mae'])
plt.title('mae')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mae')

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mse'])
plt.title('mse')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mse')

# %%
plt.title('loss')
plt.plot(history.history['loss'])

# %%
model.summary()
# Out:
# Model: "functional_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 10, 1)        0           input_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 10, 1)        0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 2)        0           reshape[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 10, 2)        0           concatenate[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 10, 40)       6880        reshape_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 10, 40)       0           lstm[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 10, 40)       12960       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10, 40)       0           lstm_4[0][0]
# __________________________________________________________________________________________________
# lstm_9 (LSTM)                   (None, 10, 40)       12960       dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 10, 40)       0           lstm_9[0][0]
# __________________________________________________________________________________________________
# lstm_15 (LSTM)                  (None, 10, 40)       12960       dropout_9[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 10, 40)       0           lstm_15[0][0]
# __________________________________________________________________________________________________
# lstm_21 (LSTM)                  (None, 10, 40)       12960       dropout_15[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 10, 40)       0           lstm_21[0][0]
# __________________________________________________________________________________________________
# lstm_28 (LSTM)                  (None, 10, 40)       12960       dropout_21[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 10, 40)       0           lstm_28[0][0]
# __________________________________________________________________________________________________
# lstm_36 (LSTM)                  (None, 10, 40)       12960       dropout_28[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 10, 40)       0           lstm_36[0][0]
# __________________________________________________________________________________________________
# lstm_43 (LSTM)                  (None, 10, 40)       12960       dropout_36[0][0]
# __________________________________________________________________________________________________
# dropout_43 (Dropout)            (None, 10, 40)       0           lstm_43[0][0]
# __________________________________________________________________________________________________
# lstm_44 (LSTM)                  (None, 10, 40)       12960       dropout_43[0][0]
# __________________________________________________________________________________________________
# dropout_44 (Dropout)            (None, 10, 40)       0           lstm_44[0][0]
# __________________________________________________________________________________________________
# lstm_45 (LSTM)                  (None, 10, 40)       12960       dropout_44[0][0]
# __________________________________________________________________________________________________
# dropout_45 (Dropout)            (None, 10, 40)       0           lstm_45[0][0]
# __________________________________________________________________________________________________
# lstm_46 (LSTM)                  (None, 10, 40)       12960       dropout_45[0][0]
# __________________________________________________________________________________________________
# dropout_46 (Dropout)            (None, 10, 40)       0           lstm_46[0][0]
# __________________________________________________________________________________________________
# lstm_47 (LSTM)                  (None, 10, 40)       12960       dropout_46[0][0]
# __________________________________________________________________________________________________
# dropout_47 (Dropout)            (None, 10, 40)       0           lstm_47[0][0]
# __________________________________________________________________________________________________
# lstm_48 (LSTM)                  (None, 10, 40)       12960       dropout_47[0][0]
# __________________________________________________________________________________________________
# dropout_48 (Dropout)            (None, 10, 40)       0           lstm_48[0][0]
# __________________________________________________________________________________________________
# lstm_49 (LSTM)                  (None, 40)           12960       dropout_48[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 40)           0           lstm_49[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            41          dropout_49[0][0]
# ==================================================================================================
# Total params: 175,401
# Trainable params: 175,401
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.metrics import mean_squared_error as mse

trainPredict = model.predict([trainX_A, trainX_G])
testPredict = model.predict([testX_A, testX_G])

# invert predictions
#scaler = MinMaxScaler(feature_range=(0, 1))
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY_A)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY_A)
# calculate root mean squared error
trainScore = math.sqrt(mse(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mse(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# calculate root mean absolute error
trainScore2 = math.sqrt(mae(trainY, trainPredict))
print('Train Score: %.2f RMAE' % (trainScore2))
testScore2 = math.sqrt(mae(testY, testPredict))
print('Test Score: %.2f RMAE' % (testScore2))

testPredictPlot = np.empty_like(datasetA)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(datasetA)-1] = testPredict
# plot baseline and predictions
plt.figure(figsize=(15, 10))
#plt.plot(datasetA[1500:])
plt.plot(datasetA[750:])
#plt.plot(trainPredictPlot)
plt.plot(testPredictPlot[750:])
plt.show()
# Out:
# Train Score: 13945.86 RMSE
# Test Score: 62159.18 RMSE
# Train Score: 95.60 RMAE
# Test Score: 205.22 RMAE

# %% [markdown]
# look back = timesteps = 10, 8 LSTM layers

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mae'])
plt.title('mae')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mae')

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mse'])
plt.title('mse')
# Out:
# timesteps :  10
# Text(0.5, 1.0, 'mse')

# %%
plt.title('loss')
plt.plot(history.history['loss'])

# %%
model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 10, 1)        0           input_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 10, 1)        0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 2)        0           reshape[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 10, 2)        0           concatenate[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 10, 40)       6880        reshape_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 10, 40)       0           lstm[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 10, 40)       12960       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 10, 40)       0           lstm_2[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 10, 40)       12960       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10, 40)       0           lstm_4[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 10, 40)       12960       dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 10, 40)       0           lstm_5[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 40)           12960       dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 40)           0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            41          dropout_6[0][0]
# ==================================================================================================
# Total params: 58,761
# Trainable params: 58,761
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.metrics import mean_squared_error as mse

trainPredict = model.predict([trainX_A, trainX_G])
testPredict = model.predict([testX_A, testX_G])

# invert predictions
#scaler = MinMaxScaler(feature_range=(0, 1))
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY_A)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY_A)
# calculate root mean squared error
trainScore = math.sqrt(mse(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mse(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# calculate root mean absolute error
trainScore2 = math.sqrt(mae(trainY, trainPredict))
print('Train Score: %.2f RMAE' % (trainScore2))
testScore2 = math.sqrt(mae(testY, testPredict))
print('Test Score: %.2f RMAE' % (testScore2))

testPredictPlot = np.empty_like(datasetA)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(datasetA)-1] = testPredict
# plot baseline and predictions
plt.figure(figsize=(15, 10))
#plt.plot(datasetA[1500:])
plt.plot(datasetA[750:])
#plt.plot(trainPredictPlot)
plt.plot(testPredictPlot[750:])
plt.show()
# Out:
# Train Score: 14716.40 RMSE
# Test Score: 62497.84 RMSE
# Train Score: 99.64 RMAE
# Test Score: 193.36 RMAE

# %%
max(testPredict)
# Out:
# array([171912.44], dtype=float32)

# %%
#testPredict

# %%
#testY_A

# %%
#datasetA[:100]
