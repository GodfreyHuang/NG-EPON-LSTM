# %%
import pandas as pd 

df = pd.read_csv('./SelfData_thesis/0630_self20GData_3to7_ONU16.csv', usecols=[2])
#df.head()

# %%
maxAi = df['Ai'].max()
maxAi
# Out:
# 1219562

# %%
df['Ai'] = df['Ai'] / maxAi #手動正規化
#df['Ri'] = df['Ri'] / 1120017 #手動正規化
print(df[20:30])

# 将dataframe 转化为 array
data = df.values
# Out:
#           Ai
# 20  0.000000
# 21  0.000000
# 22  0.017952
# 23  0.044638
# 24  0.034243
# 25  0.060051
# 26  0.076056
# 27  0.058261
# 28  0.050691
# 29  0.101548

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import datetime
import math
import itertools
from sklearn import preprocessing
import datetime
from sklearn.metrics import mean_squared_error
from math import sqrt
# Out:
# C:\Users\joker\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.

# %%
# 1 : 数据切分
result = []
time_steps = 65

for i in range(len(data)-time_steps):
    result.append(data[i:i+time_steps])

result = np.array(result)

# %%
# 训练集和测试集的数据量划分
train_size = int(0.8*len(result))

# 训练集切分
train = result[:train_size,:]

x_train = train[:, :-1]
y_train = train[:, -1][:,-1]
   
x_test = result[train_size:,:-1]
y_test = result[train_size:,-1][:,-1]

feature_nums = len(df.columns)

# 数据重塑
x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1],x_test.shape[2])

print("X_train", x_train.shape)
print("y_train", y_train.shape)
print("X_test", x_test.shape)
print("y_test", y_test.shape)
# Out:
# X_train (3223, 64, 1)
# y_train (3223,)
# X_test (806, 64, 1)
# y_test (806,)

# %%
from __future__ import print_function
import math
#importing keras modules
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Activation ,Dropout , Flatten , Conv1D , MaxPooling1D, Input
from tensorflow.keras.layers import LSTM
from tensorflow.keras import losses
from tensorflow.keras import optimizers

#def build_model(input):
#    model = Sequential()
#    model.add(Dense(128,input_shape=(input[0],input[1])))
#    model.add(Conv1D(filters=80,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform"))
#    model.add(MaxPooling1D(pool_size=2,padding='valid'))
#    model.add(Conv1D(filters=48,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform"))
#    model.add(MaxPooling1D(pool_size=2, padding='valid'))
#    model.add(LSTM(32,return_sequences=True))
#    model.add(LSTM(16,return_sequences=False))
#    model.add(Dense(32, activation="relu", kernel_initializer="uniform"))
#    model.add(Dense(1, activation="relu", kernel_initializer="uniform"))
#    model.compile(loss='mse',optimizer='adam',metrics=['mae'])
#    return model

timesteps_ = time_steps - 1
inputs = Input(shape=(timesteps_, ))
tgt1 = tf.keras.layers.Reshape((timesteps_, 1), input_shape=(timesteps_, ))(inputs)

#tgt1 = Dense(units=32, input_shape=(timesteps_, 1))(tgt1)
#1st CNN Layer
tgt2 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(tgt1)
tgt3 = MaxPooling1D(pool_size=2,padding='valid')(tgt2)
#2nd CNN Layer
tgt4 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(tgt3)
tgt5 = MaxPooling1D(pool_size=2, padding='valid')(tgt4)

#tgt6 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(tgt5)
#tgt7 = MaxPooling1D(pool_size=2, padding='valid')(tgt6)
#1st LSTM Layer
#tgt6 = LSTM(32,return_sequences=True)(tgt5) #32
#tgt6_2 = LSTM(30,return_sequences=True)(tgt6) #32
#tgt6_3 = LSTM(22,return_sequences=True)(tgt6_2) #32
#tgt7 = LSTM(16,return_sequences=False)(tgt6) #16
#Dense
tgt6 = Flatten()(tgt5)
#tgt8 = Flatten()(tgt7)
#tgt7 = Dense(32, activation="relu", kernel_initializer="uniform")(tgt6)
predictions = Dense(1, activation="relu", kernel_initializer="uniform")(tgt6)

model = Model(inputs=inputs, outputs=predictions)
model.compile(loss='mae',optimizer='Adam',metrics=['mse','mae'])

# %%
#model = build_model([9,1,1]) #[x_train shape的第二個數字, x_train shape的第三個數字, 1]
#Summary of the Model
print(model.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64)]              0
# _________________________________________________________________
# reshape (Reshape)            (None, 64, 1)             0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 64, 32)            64
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 32, 32)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 32, 32)            1056
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 16, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 513
# =================================================================
# Total params: 1,633
# Trainable params: 1,633
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from timeit import default_timer as timer
start = timer()
history = model.fit(x_train,
                    y_train,
                    batch_size=64,
                    epochs=60,
                    validation_split=0.2,
                    verbose=2)
end = timer()
print(end - start)
# Out:
# Epoch 1/60
# 41/41 - 0s - loss: 0.0414 - mse: 0.0052 - mae: 0.0414 - val_loss: 0.0400 - val_mse: 0.0055 - val_mae: 0.0400
# Epoch 2/60
# 41/41 - 0s - loss: 0.0393 - mse: 0.0048 - mae: 0.0393 - val_loss: 0.0394 - val_mse: 0.0054 - val_mae: 0.0394
# Epoch 3/60
# 41/41 - 0s - loss: 0.0384 - mse: 0.0046 - mae: 0.0384 - val_loss: 0.0392 - val_mse: 0.0053 - val_mae: 0.0392
# Epoch 4/60
# 41/41 - 0s - loss: 0.0380 - mse: 0.0046 - mae: 0.0380 - val_loss: 0.0392 - val_mse: 0.0054 - val_mae: 0.0392
# Epoch 5/60
# 41/41 - 0s - loss: 0.0371 - mse: 0.0044 - mae: 0.0371 - val_loss: 0.0393 - val_mse: 0.0054 - val_mae: 0.0393
# Epoch 6/60
# 41/41 - 0s - loss: 0.0367 - mse: 0.0045 - mae: 0.0367 - val_loss: 0.0385 - val_mse: 0.0054 - val_mae: 0.0385
# Epoch 7/60
# 41/41 - 0s - loss: 0.0364 - mse: 0.0045 - mae: 0.0364 - val_loss: 0.0377 - val_mse: 0.0051 - val_mae: 0.0377
# Epoch 8/60
# 41/41 - 0s - loss: 0.0360 - mse: 0.0046 - mae: 0.0360 - val_loss: 0.0371 - val_mse: 0.0052 - val_mae: 0.0371
# Epoch 9/60
# 41/41 - 0s - loss: 0.0357 - mse: 0.0045 - mae: 0.0357 - val_loss: 0.0375 - val_mse: 0.0053 - val_mae: 0.0375
# Epoch 10/60
# 41/41 - 0s - loss: 0.0355 - mse: 0.0046 - mae: 0.0355 - val_loss: 0.0374 - val_mse: 0.0055 - val_mae: 0.0374
# Epoch 11/60
# 41/41 - 0s - loss: 0.0351 - mse: 0.0046 - mae: 0.0351 - val_loss: 0.0373 - val_mse: 0.0055 - val_mae: 0.0373
# Epoch 12/60
# 41/41 - 0s - loss: 0.0350 - mse: 0.0047 - mae: 0.0350 - val_loss: 0.0371 - val_mse: 0.0054 - val_mae: 0.0371
# Epoch 13/60
# 41/41 - 0s - loss: 0.0353 - mse: 0.0046 - mae: 0.0353 - val_loss: 0.0380 - val_mse: 0.0057 - val_mae: 0.0380
# Epoch 14/60
# 41/41 - 0s - loss: 0.0354 - mse: 0.0048 - mae: 0.0354 - val_loss: 0.0374 - val_mse: 0.0053 - val_mae: 0.0374
# Epoch 15/60
# 41/41 - 0s - loss: 0.0349 - mse: 0.0047 - mae: 0.0349 - val_loss: 0.0373 - val_mse: 0.0053 - val_mae: 0.0373
# Epoch 16/60
# 41/41 - 0s - loss: 0.0350 - mse: 0.0046 - mae: 0.0350 - val_loss: 0.0372 - val_mse: 0.0053 - val_mae: 0.0372
# Epoch 17/60
# 41/41 - 0s - loss: 0.0350 - mse: 0.0047 - mae: 0.0350 - val_loss: 0.0370 - val_mse: 0.0055 - val_mae: 0.0370
# Epoch 18/60
# 41/41 - 0s - loss: 0.0347 - mse: 0.0048 - mae: 0.0347 - val_loss: 0.0371 - val_mse: 0.0055 - val_mae: 0.0371
# Epoch 19/60
# 41/41 - 0s - loss: 0.0348 - mse: 0.0047 - mae: 0.0348 - val_loss: 0.0371 - val_mse: 0.0054 - val_mae: 0.0371
# Epoch 20/60
# 41/41 - 0s - loss: 0.0349 - mse: 0.0047 - mae: 0.0349 - val_loss: 0.0370 - val_mse: 0.0055 - val_mae: 0.0370
# Epoch 21/60
# 41/41 - 0s - loss: 0.0349 - mse: 0.0047 - mae: 0.0349 - val_loss: 0.0373 - val_mse: 0.0054 - val_mae: 0.0373
# Epoch 22/60
# 41/41 - 0s - loss: 0.0347 - mse: 0.0047 - mae: 0.0347 - val_loss: 0.0372 - val_mse: 0.0054 - val_mae: 0.0372
# Epoch 23/60
# 41/41 - 0s - loss: 0.0348 - mse: 0.0048 - mae: 0.0348 - val_loss: 0.0371 - val_mse: 0.0056 - val_mae: 0.0371
# Epoch 24/60
# 41/41 - 0s - loss: 0.0346 - mse: 0.0046 - mae: 0.0346 - val_loss: 0.0387 - val_mse: 0.0060 - val_mae: 0.0387
# Epoch 25/60
# 41/41 - 0s - loss: 0.0349 - mse: 0.0048 - mae: 0.0349 - val_loss: 0.0371 - val_mse: 0.0056 - val_mae: 0.0371
# Epoch 26/60
# 41/41 - 0s - loss: 0.0349 - mse: 0.0048 - mae: 0.0349 - val_loss: 0.0374 - val_mse: 0.0056 - val_mae: 0.0374
# Epoch 27/60
# 41/41 - 0s - loss: 0.0347 - mse: 0.0048 - mae: 0.0347 - val_loss: 0.0369 - val_mse: 0.0056 - val_mae: 0.0369
# Epoch 28/60
# 41/41 - 0s - loss: 0.0346 - mse: 0.0047 - mae: 0.0346 - val_loss: 0.0375 - val_mse: 0.0057 - val_mae: 0.0375
# Epoch 29/60
# 41/41 - 0s - loss: 0.0347 - mse: 0.0048 - mae: 0.0347 - val_loss: 0.0371 - val_mse: 0.0055 - val_mae: 0.0371
# Epoch 30/60
# 41/41 - 0s - loss: 0.0352 - mse: 0.0048 - mae: 0.0352 - val_loss: 0.0373 - val_mse: 0.0054 - val_mae: 0.0373
# Epoch 31/60
# 41/41 - 0s - loss: 0.0348 - mse: 0.0047 - mae: 0.0348 - val_loss: 0.0370 - val_mse: 0.0056 - val_mae: 0.0370
# Epoch 32/60
# 41/41 - 0s - loss: 0.0346 - mse: 0.0048 - mae: 0.0346 - val_loss: 0.0378 - val_mse: 0.0057 - val_mae: 0.0378
# Epoch 33/60
# 41/41 - 0s - loss: 0.0346 - mse: 0.0047 - mae: 0.0346 - val_loss: 0.0372 - val_mse: 0.0054 - val_mae: 0.0372
# Epoch 34/60
# 41/41 - 0s - loss: 0.0345 - mse: 0.0048 - mae: 0.0345 - val_loss: 0.0373 - val_mse: 0.0058 - val_mae: 0.0373
# Epoch 35/60
# 41/41 - 0s - loss: 0.0345 - mse: 0.0047 - mae: 0.0345 - val_loss: 0.0372 - val_mse: 0.0056 - val_mae: 0.0372
# Epoch 36/60
# 41/41 - 0s - loss: 0.0345 - mse: 0.0047 - mae: 0.0345 - val_loss: 0.0386 - val_mse: 0.0060 - val_mae: 0.0386
# Epoch 37/60
# 41/41 - 0s - loss: 0.0348 - mse: 0.0048 - mae: 0.0348 - val_loss: 0.0373 - val_mse: 0.0056 - val_mae: 0.0373
# Epoch 38/60
# 41/41 - 0s - loss: 0.0346 - mse: 0.0047 - mae: 0.0346 - val_loss: 0.0373 - val_mse: 0.0057 - val_mae: 0.0373
# Epoch 39/60
# 41/41 - 0s - loss: 0.0345 - mse: 0.0047 - mae: 0.0345 - val_loss: 0.0373 - val_mse: 0.0056 - val_mae: 0.0373
# Epoch 40/60
# 41/41 - 0s - loss: 0.0345 - mse: 0.0048 - mae: 0.0345 - val_loss: 0.0373 - val_mse: 0.0055 - val_mae: 0.0373
# Epoch 41/60
# 41/41 - 0s - loss: 0.0346 - mse: 0.0047 - mae: 0.0346 - val_loss: 0.0378 - val_mse: 0.0057 - val_mae: 0.0378
# Epoch 42/60
# 41/41 - 0s - loss: 0.0345 - mse: 0.0047 - mae: 0.0345 - val_loss: 0.0368 - val_mse: 0.0054 - val_mae: 0.0368
# Epoch 43/60
# 41/41 - 0s - loss: 0.0346 - mse: 0.0047 - mae: 0.0346 - val_loss: 0.0369 - val_mse: 0.0055 - val_mae: 0.0369
# Epoch 44/60
# 41/41 - 0s - loss: 0.0348 - mse: 0.0048 - mae: 0.0348 - val_loss: 0.0387 - val_mse: 0.0060 - val_mae: 0.0387
# Epoch 45/60
# 41/41 - 0s - loss: 0.0345 - mse: 0.0047 - mae: 0.0345 - val_loss: 0.0396 - val_mse: 0.0062 - val_mae: 0.0396
# Epoch 46/60
# 41/41 - 0s - loss: 0.0347 - mse: 0.0048 - mae: 0.0347 - val_loss: 0.0372 - val_mse: 0.0057 - val_mae: 0.0372
# Epoch 47/60
# 41/41 - 0s - loss: 0.0344 - mse: 0.0047 - mae: 0.0344 - val_loss: 0.0369 - val_mse: 0.0056 - val_mae: 0.0369
# Epoch 48/60
# 41/41 - 0s - loss: 0.0345 - mse: 0.0047 - mae: 0.0345 - val_loss: 0.0372 - val_mse: 0.0056 - val_mae: 0.0372
# Epoch 49/60
# 41/41 - 0s - loss: 0.0346 - mse: 0.0047 - mae: 0.0346 - val_loss: 0.0374 - val_mse: 0.0057 - val_mae: 0.0374
# Epoch 50/60
# 41/41 - 0s - loss: 0.0344 - mse: 0.0047 - mae: 0.0344 - val_loss: 0.0371 - val_mse: 0.0056 - val_mae: 0.0371
# Epoch 51/60
# 41/41 - 0s - loss: 0.0342 - mse: 0.0047 - mae: 0.0342 - val_loss: 0.0376 - val_mse: 0.0057 - val_mae: 0.0376
# Epoch 52/60
# 41/41 - 0s - loss: 0.0347 - mse: 0.0047 - mae: 0.0347 - val_loss: 0.0368 - val_mse: 0.0055 - val_mae: 0.0368
# Epoch 53/60
# 41/41 - 0s - loss: 0.0347 - mse: 0.0048 - mae: 0.0347 - val_loss: 0.0368 - val_mse: 0.0054 - val_mae: 0.0368
# Epoch 54/60
# 41/41 - 0s - loss: 0.0345 - mse: 0.0048 - mae: 0.0345 - val_loss: 0.0369 - val_mse: 0.0055 - val_mae: 0.0369
# Epoch 55/60
# 41/41 - 0s - loss: 0.0348 - mse: 0.0047 - mae: 0.0348 - val_loss: 0.0375 - val_mse: 0.0058 - val_mae: 0.0375
# Epoch 56/60
# 41/41 - 0s - loss: 0.0345 - mse: 0.0047 - mae: 0.0345 - val_loss: 0.0373 - val_mse: 0.0057 - val_mae: 0.0373
# Epoch 57/60
# 41/41 - 0s - loss: 0.0343 - mse: 0.0046 - mae: 0.0343 - val_loss: 0.0372 - val_mse: 0.0054 - val_mae: 0.0372
# Epoch 58/60
# 41/41 - 0s - loss: 0.0343 - mse: 0.0047 - mae: 0.0343 - val_loss: 0.0370 - val_mse: 0.0056 - val_mae: 0.0370
# Epoch 59/60
# 41/41 - 0s - loss: 0.0343 - mse: 0.0046 - mae: 0.0343 - val_loss: 0.0370 - val_mse: 0.0054 - val_mae: 0.0370
# Epoch 60/60
# 41/41 - 0s - loss: 0.0345 - mse: 0.0048 - mae: 0.0345 - val_loss: 0.0368 - val_mse: 0.0054 - val_mae: 0.0368
# 7.2701894000000005

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'mse', 'mae', 'val_loss', 'val_mse', 'val_mae'])

# %%
# 画出训练集和验证集的损失曲线

import matplotlib.pyplot as plt

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
loss_values50 = loss_values[0:150]
val_loss_values50 = val_loss_values[0:150]
epochs = range(1, len(loss_values50) + 1)
plt.plot(epochs, loss_values50, 'b',color = 'blue', label='Training loss')
plt.plot(epochs, val_loss_values50, 'b',color='orange', label='Validation loss')
plt.rc('font', size = 18)
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.xticks(epochs)
fig = plt.gcf()
fig.set_size_inches(15,7)
#fig.savefig('img/tcstest&validationlosscnn.png', dpi=300)
plt.show()

# %%
# 画出训练集和验证集的误差图像

#mae = history_dict['mean_absolute_error']
#vmae = history_dict['val_mean_absolute_error']
mae = history.history['mae']
vmae = history.history['val_mae']
epochs = range(1, len(mae) + 1)
plt.plot(epochs, mae, 'b',color = 'blue', label='Training error')
plt.plot(epochs, vmae, 'b',color='orange', label='Validation error')
plt.title('Training and validation error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.legend()
plt.xticks(epochs)
fig = plt.gcf()
fig.set_size_inches(15,7)
#fig.savefig('img/tcstest&validationerrorcnn.png', dpi=300)
plt.show()

# %%
model.metrics_names
# Out:
# ['loss', 'mse', 'mae']

# %%
trainScore = model.evaluate(x_train, y_train, verbose=0)
testScore = model.evaluate(x_test, y_test, verbose=0)

# %%
#predicting values for y_test
p = model.predict(x_test)

# %%
plt.plot(y_test, label='y_test')
plt.plot(p, label='prediction')
plt.xlabel('test cycle')
plt.ylabel('predict Ai')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(15, 5)
#fig.savefig('img/tcstestcnn.png', dpi=300)
plt.show()

# %%
p1= model.predict(x_train)

# %%
plt.plot(y_train, label='y_train')
x = np.array(range(2578,3223)) #range(x_train shape第一個數字的0.8倍, x_train shape第一個數字)
plt.plot(x,p1[2578:],color = 'magenta',label ='prediction on validating samples') #p1[數字:] 數字代表x_train shape第一個數字的0.8倍
plt.plot(p1[:2578],color='red', label='prediction on training samples')
#x = np.array(range(29512,36890)) #range(x_train shape第一個數字的0.8倍, x_train shape第一個數字)
#plt.plot(x,p1[29512:],color = 'magenta',label ='prediction on validating samples')
#plt.plot(y_train,color='blue', label='y_train')
plt.xlabel('No. of Trading Days')
plt.ylabel('Close Value (scaled)')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(20,10)
#fig.savefig('img/tcstraincnn.png', dpi=300)
plt.show()

# %%
#手動正規化
y = y_test * maxAi   # 原始数据经过除以10000进行缩放，因此乘以10000,返回到原始数据规模
y_pred = p.reshape(806)  # 测试集数据大小为265
y_pred = y_pred * maxAi   # 原始数据经过除以10000进行缩放，因此乘以10000,返回到原始数据规模

# %%
from sklearn.metrics import mean_absolute_error

# %%
print('Trainscore RMSE \tTrain Mean abs Error \tTestscore Rmse \t Test Mean abs Error')
print('%.9f \t\t %.9f \t\t %.9f \t\t %.9f' % (math.sqrt(trainScore[0]),trainScore[1],math.sqrt(testScore[0]),testScore[1]))
# Out:
# Trainscore RMSE 	Train Mean abs Error 	Testscore Rmse 	 Test Mean abs Error
# 0.186351977 		 0.004746947 		 0.211329388 		 0.012393625

# %%
print('mean absolute error \t mean absolute percentage error')
print(' %.9f \t\t\t %.9f' % (mean_absolute_error(y,y_pred),(np.mean(np.abs((y - y_pred) / y)) * 100)))
# Out:
# mean absolute error 	 mean absolute percentage error
#  54465.770643650 			 nan
# C:\Users\joker\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# C:\Users\joker\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %%
Ytrain = y_train * maxAi
Ytest = y_test * maxAi

P1 = p1 * maxAi
PP = p * maxAi

# %%
Y = np.concatenate((Ytrain,Ytest),axis = 0)
plt.plot(Y, label='Y')
P = np.concatenate((P1,PP),axis = 0)
#plotting the complete Y set with predicted values on x_train and x_test(variable p1 & p respectively given above)
#for 
plt.plot(P[:2578],color='red', label='prediction on training samples') #p[:數字] 數字代表x_train shape第一個數字的0.8倍
#for validating samples
z = np.array(range(2578,3223)) #range(x_train shape第一個數字的0.8倍, x_train shape第一個數字)
plt.plot(z,P[2578:3223],color = 'orange',label ='prediction on validating samples') #P[x_train shape第一個數字的0.8倍:x_train shape第一個數字]
#for testing samples
x = np.array(range(3223,4029)) #range(x_train shape第一個數字, x_train shape第一個數字 + x_test shape第一個數字)
plt.plot(x,P[3223:],color = 'purple',label ='prediction on testing samples(x_test)') #p[數字:] 數字代表x_train shape第一個數字

#plt.plot(Y,color='blue', label='Y')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(20,12)
plt.show()

# %%
plt.plot(Ytest[:300], label='y_test')
plt.plot(PP[:300], label='prediction')
plt.title('ONU16 request')
plt.xlabel('Test Case')
plt.ylabel('Ai')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(15, 10)
#fig.savefig('img/tcstestcnn.png', dpi=300)
plt.legend()
plt.show()

# %%
print('timesteps : ',timesteps_)
plt.plot(history.history['mae'])
plt.title('mae')
# Out:
# timesteps :  64
# Text(0.5, 1.0, 'mae')

# %%
print('timesteps : ',timesteps_)
plt.plot(history.history['mse'])
plt.title('mse')
# Out:
# timesteps :  64
# Text(0.5, 1.0, 'mse')

# %%
plt.title('loss')
plt.plot(history.history['loss'])

# %%
model.save('./SelfData_thesis/0704_U20D00_CNN_ONU16_AipredictAi_1219562_2layer_timesteps64_Epoch60.h5', include_optimizer=False)
