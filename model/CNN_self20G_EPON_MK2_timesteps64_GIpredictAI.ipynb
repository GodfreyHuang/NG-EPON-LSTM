# %%
import pandas as pd 

df = pd.read_csv('./SelfData_thesis/0630_self20GData_3to7_ONU16.csv', usecols=[1])
#df.head()

# %%
maxAi = df['Gi'].max()
maxAi
# Out:
# 195000

# %%
df['Gi'] = df['Gi'] / maxAi #手動正規化
#df['Ri'] = df['Ri'] / 1120017 #手動正規化
print(df[:20])

# 将dataframe 转化为 array
data = df.values
# Out:
#           Gi
# 0   0.000728
# 1   0.000282
# 2   0.000769
# 3   0.000236
# 4   0.000821
# 5   0.000179
# 6   0.000882
# 7   0.000113
# 8   0.000959
# 9   0.000026
# 10  0.001051
# 11  0.000000
# 12  0.000000
# 13  0.000000
# 14  0.000000
# 15  0.000000
# 16  0.000000
# 17  0.000000
# 18  0.000000
# 19  0.000000

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import datetime
import math
import itertools
from sklearn import preprocessing
import datetime
from sklearn.metrics import mean_squared_error
from math import sqrt
# Out:
# C:\Users\joker\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.

# %%
# 1 : 数据切分
result = []
time_steps = 65

for i in range(len(data)-time_steps):
    result.append(data[i:i+time_steps])

result = np.array(result)

# %%
# 训练集和测试集的数据量划分
train_size = int(0.8*len(result))

# 训练集切分
train = result[:train_size,:]

x_train = train[:, :-1]
y_train = train[:, -1][:,-1]
   
x_test = result[train_size:,:-1]
y_test = result[train_size:,-1][:,-1]

feature_nums = len(df.columns)

# 数据重塑
x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1],x_test.shape[2])

print("X_train", x_train.shape)
print("y_train", y_train.shape)
print("X_test", x_test.shape)
print("y_test", y_test.shape)
# Out:
# X_train (3223, 64, 1)
# y_train (3223,)
# X_test (806, 64, 1)
# y_test (806,)

# %%
from __future__ import print_function
import math
#importing keras modules
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Activation ,Dropout , Flatten , Conv1D , MaxPooling1D, Input
from tensorflow.keras.layers import LSTM
from tensorflow.keras import losses
from tensorflow.keras import optimizers

#def build_model(input):
#    model = Sequential()
#    model.add(Dense(128,input_shape=(input[0],input[1])))
#    model.add(Conv1D(filters=80,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform"))
#    model.add(MaxPooling1D(pool_size=2,padding='valid'))
#    model.add(Conv1D(filters=48,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform"))
#    model.add(MaxPooling1D(pool_size=2, padding='valid'))
#    model.add(LSTM(32,return_sequences=True))
#    model.add(LSTM(16,return_sequences=False))
#    model.add(Dense(32, activation="relu", kernel_initializer="uniform"))
#    model.add(Dense(1, activation="relu", kernel_initializer="uniform"))
#    model.compile(loss='mse',optimizer='adam',metrics=['mae'])
#    return model

timesteps_ = time_steps - 1
inputs = Input(shape=(timesteps_, ))
tgt1 = tf.keras.layers.Reshape((timesteps_, 1), input_shape=(timesteps_, ))(inputs)

tgt1 = Dense(units=32, input_shape=(timesteps_, 1))(tgt1)
#1st CNN Layer
tgt2 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(tgt1)
tgt3 = MaxPooling1D(pool_size=2,padding='valid')(tgt2)
#2nd CNN Layer
tgt4 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(tgt3)
tgt5 = MaxPooling1D(pool_size=2, padding='valid')(tgt4)

#tgt6 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(tgt5)
#tgt7 = MaxPooling1D(pool_size=2, padding='valid')(tgt6)
#1st LSTM Layer
#tgt6 = LSTM(32,return_sequences=True)(tgt5) #32
#tgt6_2 = LSTM(30,return_sequences=True)(tgt6) #32
#tgt6_3 = LSTM(22,return_sequences=True)(tgt6_2) #32
#tgt7 = LSTM(16,return_sequences=False)(tgt6) #16
#Dense
tgt6 = Flatten()(tgt5)
#tgt8 = Flatten()(tgt7)
#tgt7 = Dense(32, activation="relu", kernel_initializer="uniform")(tgt6)
predictions = Dense(1, activation="relu", kernel_initializer="uniform")(tgt6)

model = Model(inputs=inputs, outputs=predictions)
model.compile(loss='mae',optimizer='Adam',metrics=['mse','mae'])

# %%
#model = build_model([9,1,1]) #[x_train shape的第二個數字, x_train shape的第三個數字, 1]
#Summary of the Model
print(model.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64)]              0
# _________________________________________________________________
# reshape (Reshape)            (None, 64, 1)             0
# _________________________________________________________________
# dense (Dense)                (None, 64, 32)            64
# _________________________________________________________________
# conv1d (Conv1D)              (None, 64, 32)            1056
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 32, 32)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 32, 32)            1056
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 16, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 2,689
# Trainable params: 2,689
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from timeit import default_timer as timer
start = timer()
history = model.fit(x_train,
                    y_train,
                    batch_size=64,
                    epochs=100,
                    validation_split=0.2,
                    verbose=2)
end = timer()
print(end - start)
# Out:
# Epoch 1/100
# 41/41 - 0s - loss: 0.2683 - mse: 0.1155 - mae: 0.2683 - val_loss: 0.2408 - val_mse: 0.0868 - val_mae: 0.2408
# Epoch 2/100
# 41/41 - 0s - loss: 0.2378 - mse: 0.0868 - mae: 0.2378 - val_loss: 0.2302 - val_mse: 0.0829 - val_mae: 0.2302
# Epoch 3/100
# 41/41 - 0s - loss: 0.2223 - mse: 0.0810 - mae: 0.2223 - val_loss: 0.2202 - val_mse: 0.0772 - val_mae: 0.2202
# Epoch 4/100
# 41/41 - 0s - loss: 0.2161 - mse: 0.0798 - mae: 0.2161 - val_loss: 0.2206 - val_mse: 0.0742 - val_mae: 0.2206
# Epoch 5/100
# 41/41 - 0s - loss: 0.2116 - mse: 0.0768 - mae: 0.2116 - val_loss: 0.2183 - val_mse: 0.0742 - val_mae: 0.2183
# Epoch 6/100
# 41/41 - 0s - loss: 0.2101 - mse: 0.0760 - mae: 0.2101 - val_loss: 0.2171 - val_mse: 0.0751 - val_mae: 0.2171
# Epoch 7/100
# 41/41 - 0s - loss: 0.2094 - mse: 0.0760 - mae: 0.2094 - val_loss: 0.2170 - val_mse: 0.0744 - val_mae: 0.2170
# Epoch 8/100
# 41/41 - 0s - loss: 0.2091 - mse: 0.0761 - mae: 0.2091 - val_loss: 0.2179 - val_mse: 0.0774 - val_mae: 0.2179
# Epoch 9/100
# 41/41 - 0s - loss: 0.2095 - mse: 0.0764 - mae: 0.2095 - val_loss: 0.2155 - val_mse: 0.0746 - val_mae: 0.2155
# Epoch 10/100
# 41/41 - 0s - loss: 0.2085 - mse: 0.0758 - mae: 0.2085 - val_loss: 0.2156 - val_mse: 0.0745 - val_mae: 0.2156
# Epoch 11/100
# 41/41 - 0s - loss: 0.2070 - mse: 0.0750 - mae: 0.2070 - val_loss: 0.2285 - val_mse: 0.0890 - val_mae: 0.2285
# Epoch 12/100
# 41/41 - 0s - loss: 0.2082 - mse: 0.0767 - mae: 0.2082 - val_loss: 0.2156 - val_mse: 0.0742 - val_mae: 0.2156
# Epoch 13/100
# 41/41 - 0s - loss: 0.2054 - mse: 0.0748 - mae: 0.2054 - val_loss: 0.2154 - val_mse: 0.0733 - val_mae: 0.2154
# Epoch 14/100
# 41/41 - 0s - loss: 0.2052 - mse: 0.0746 - mae: 0.2052 - val_loss: 0.2172 - val_mse: 0.0745 - val_mae: 0.2172
# Epoch 15/100
# 41/41 - 0s - loss: 0.2037 - mse: 0.0745 - mae: 0.2037 - val_loss: 0.2150 - val_mse: 0.0755 - val_mae: 0.2150
# Epoch 16/100
# 41/41 - 0s - loss: 0.2051 - mse: 0.0761 - mae: 0.2051 - val_loss: 0.2152 - val_mse: 0.0763 - val_mae: 0.2152
# Epoch 17/100
# 41/41 - 0s - loss: 0.2037 - mse: 0.0740 - mae: 0.2037 - val_loss: 0.2257 - val_mse: 0.0875 - val_mae: 0.2257
# Epoch 18/100
# 41/41 - 0s - loss: 0.2028 - mse: 0.0743 - mae: 0.2028 - val_loss: 0.2160 - val_mse: 0.0748 - val_mae: 0.2160
# Epoch 19/100
# 41/41 - 0s - loss: 0.2017 - mse: 0.0739 - mae: 0.2017 - val_loss: 0.2139 - val_mse: 0.0745 - val_mae: 0.2139
# Epoch 20/100
# 41/41 - 0s - loss: 0.2036 - mse: 0.0740 - mae: 0.2036 - val_loss: 0.2221 - val_mse: 0.0845 - val_mae: 0.2221
# Epoch 21/100
# 41/41 - 0s - loss: 0.2028 - mse: 0.0745 - mae: 0.2028 - val_loss: 0.2133 - val_mse: 0.0747 - val_mae: 0.2133
# Epoch 22/100
# 41/41 - 0s - loss: 0.2022 - mse: 0.0744 - mae: 0.2022 - val_loss: 0.2145 - val_mse: 0.0764 - val_mae: 0.2145
# Epoch 23/100
# 41/41 - 0s - loss: 0.2059 - mse: 0.0759 - mae: 0.2059 - val_loss: 0.2160 - val_mse: 0.0741 - val_mae: 0.2160
# Epoch 24/100
# 41/41 - 0s - loss: 0.2014 - mse: 0.0731 - mae: 0.2014 - val_loss: 0.2191 - val_mse: 0.0812 - val_mae: 0.2191
# Epoch 25/100
# 41/41 - 0s - loss: 0.2013 - mse: 0.0734 - mae: 0.2013 - val_loss: 0.2132 - val_mse: 0.0752 - val_mae: 0.2132
# Epoch 26/100
# 41/41 - 0s - loss: 0.2018 - mse: 0.0741 - mae: 0.2018 - val_loss: 0.2143 - val_mse: 0.0738 - val_mae: 0.2143
# Epoch 27/100
# 41/41 - 0s - loss: 0.2005 - mse: 0.0728 - mae: 0.2005 - val_loss: 0.2122 - val_mse: 0.0738 - val_mae: 0.2122
# Epoch 28/100
# 41/41 - 0s - loss: 0.2000 - mse: 0.0733 - mae: 0.2000 - val_loss: 0.2140 - val_mse: 0.0759 - val_mae: 0.2140
# Epoch 29/100
# 41/41 - 0s - loss: 0.1994 - mse: 0.0728 - mae: 0.1994 - val_loss: 0.2133 - val_mse: 0.0752 - val_mae: 0.2133
# Epoch 30/100
# 41/41 - 0s - loss: 0.2017 - mse: 0.0740 - mae: 0.2017 - val_loss: 0.2122 - val_mse: 0.0746 - val_mae: 0.2122
# Epoch 31/100
# 41/41 - 0s - loss: 0.2003 - mse: 0.0725 - mae: 0.2003 - val_loss: 0.2128 - val_mse: 0.0752 - val_mae: 0.2128
# Epoch 32/100
# 41/41 - 0s - loss: 0.1993 - mse: 0.0724 - mae: 0.1993 - val_loss: 0.2157 - val_mse: 0.0785 - val_mae: 0.2157
# Epoch 33/100
# 41/41 - 0s - loss: 0.1994 - mse: 0.0726 - mae: 0.1994 - val_loss: 0.2129 - val_mse: 0.0755 - val_mae: 0.2129
# Epoch 34/100
# 41/41 - 0s - loss: 0.1984 - mse: 0.0721 - mae: 0.1984 - val_loss: 0.2100 - val_mse: 0.0729 - val_mae: 0.2100
# Epoch 35/100
# 41/41 - 0s - loss: 0.1985 - mse: 0.0721 - mae: 0.1985 - val_loss: 0.2116 - val_mse: 0.0740 - val_mae: 0.2116
# Epoch 36/100
# 41/41 - 0s - loss: 0.1988 - mse: 0.0721 - mae: 0.1988 - val_loss: 0.2125 - val_mse: 0.0748 - val_mae: 0.2125
# Epoch 37/100
# 41/41 - 0s - loss: 0.1983 - mse: 0.0721 - mae: 0.1983 - val_loss: 0.2116 - val_mse: 0.0736 - val_mae: 0.2116
# Epoch 38/100
# 41/41 - 0s - loss: 0.1990 - mse: 0.0728 - mae: 0.1990 - val_loss: 0.2181 - val_mse: 0.0804 - val_mae: 0.2181
# Epoch 39/100
# 41/41 - 0s - loss: 0.1997 - mse: 0.0722 - mae: 0.1997 - val_loss: 0.2125 - val_mse: 0.0747 - val_mae: 0.2125
# Epoch 40/100
# 41/41 - 0s - loss: 0.2009 - mse: 0.0745 - mae: 0.2009 - val_loss: 0.2135 - val_mse: 0.0769 - val_mae: 0.2135
# Epoch 41/100
# 41/41 - 0s - loss: 0.1983 - mse: 0.0726 - mae: 0.1983 - val_loss: 0.2151 - val_mse: 0.0780 - val_mae: 0.2151
# Epoch 42/100
# 41/41 - 0s - loss: 0.1980 - mse: 0.0722 - mae: 0.1980 - val_loss: 0.2148 - val_mse: 0.0774 - val_mae: 0.2148
# Epoch 43/100
# 41/41 - 0s - loss: 0.1987 - mse: 0.0718 - mae: 0.1987 - val_loss: 0.2297 - val_mse: 0.0900 - val_mae: 0.2297
# Epoch 44/100
# 41/41 - 0s - loss: 0.1995 - mse: 0.0734 - mae: 0.1995 - val_loss: 0.2118 - val_mse: 0.0750 - val_mae: 0.2118
# Epoch 45/100
# 41/41 - 0s - loss: 0.1994 - mse: 0.0729 - mae: 0.1994 - val_loss: 0.2109 - val_mse: 0.0732 - val_mae: 0.2109
# Epoch 46/100
# 41/41 - 0s - loss: 0.1982 - mse: 0.0719 - mae: 0.1982 - val_loss: 0.2101 - val_mse: 0.0733 - val_mae: 0.2101
# Epoch 47/100
# 41/41 - 0s - loss: 0.1977 - mse: 0.0722 - mae: 0.1977 - val_loss: 0.2143 - val_mse: 0.0773 - val_mae: 0.2143
# Epoch 48/100
# 41/41 - 0s - loss: 0.1972 - mse: 0.0717 - mae: 0.1972 - val_loss: 0.2104 - val_mse: 0.0732 - val_mae: 0.2104
# Epoch 49/100
# 41/41 - 0s - loss: 0.1959 - mse: 0.0709 - mae: 0.1959 - val_loss: 0.2102 - val_mse: 0.0738 - val_mae: 0.2102
# Epoch 50/100
# 41/41 - 0s - loss: 0.1963 - mse: 0.0713 - mae: 0.1963 - val_loss: 0.2107 - val_mse: 0.0727 - val_mae: 0.2107
# Epoch 51/100
# 41/41 - 0s - loss: 0.1977 - mse: 0.0724 - mae: 0.1977 - val_loss: 0.2208 - val_mse: 0.0833 - val_mae: 0.2208
# Epoch 52/100
# 41/41 - 0s - loss: 0.1995 - mse: 0.0727 - mae: 0.1995 - val_loss: 0.2130 - val_mse: 0.0763 - val_mae: 0.2130
# Epoch 53/100
# 41/41 - 0s - loss: 0.1965 - mse: 0.0714 - mae: 0.1965 - val_loss: 0.2167 - val_mse: 0.0795 - val_mae: 0.2167
# Epoch 54/100
# 41/41 - 0s - loss: 0.1983 - mse: 0.0720 - mae: 0.1983 - val_loss: 0.2127 - val_mse: 0.0759 - val_mae: 0.2127
# Epoch 55/100
# 41/41 - 0s - loss: 0.1973 - mse: 0.0713 - mae: 0.1973 - val_loss: 0.2138 - val_mse: 0.0774 - val_mae: 0.2138
# Epoch 56/100
# 41/41 - 0s - loss: 0.1988 - mse: 0.0727 - mae: 0.1988 - val_loss: 0.2113 - val_mse: 0.0726 - val_mae: 0.2113
# Epoch 57/100
# 41/41 - 0s - loss: 0.1955 - mse: 0.0701 - mae: 0.1955 - val_loss: 0.2095 - val_mse: 0.0730 - val_mae: 0.2095
# Epoch 58/100
# 41/41 - 0s - loss: 0.1963 - mse: 0.0710 - mae: 0.1963 - val_loss: 0.2090 - val_mse: 0.0723 - val_mae: 0.2090
# Epoch 59/100
# 41/41 - 0s - loss: 0.1949 - mse: 0.0700 - mae: 0.1949 - val_loss: 0.2173 - val_mse: 0.0810 - val_mae: 0.2173
# Epoch 60/100
# 41/41 - 0s - loss: 0.1971 - mse: 0.0718 - mae: 0.1971 - val_loss: 0.2187 - val_mse: 0.0814 - val_mae: 0.2187
# Epoch 61/100
# 41/41 - 0s - loss: 0.1962 - mse: 0.0708 - mae: 0.1962 - val_loss: 0.2107 - val_mse: 0.0743 - val_mae: 0.2107
# Epoch 62/100
# 41/41 - 0s - loss: 0.1950 - mse: 0.0704 - mae: 0.1950 - val_loss: 0.2095 - val_mse: 0.0739 - val_mae: 0.2095
# Epoch 63/100
# 41/41 - 0s - loss: 0.1954 - mse: 0.0703 - mae: 0.1954 - val_loss: 0.2141 - val_mse: 0.0780 - val_mae: 0.2141
# Epoch 64/100
# 41/41 - 0s - loss: 0.1972 - mse: 0.0713 - mae: 0.1972 - val_loss: 0.2107 - val_mse: 0.0746 - val_mae: 0.2107
# Epoch 65/100
# 41/41 - 0s - loss: 0.1970 - mse: 0.0707 - mae: 0.1970 - val_loss: 0.2115 - val_mse: 0.0752 - val_mae: 0.2115
# Epoch 66/100
# 41/41 - 0s - loss: 0.1955 - mse: 0.0708 - mae: 0.1955 - val_loss: 0.2118 - val_mse: 0.0725 - val_mae: 0.2118
# Epoch 67/100
# 41/41 - 0s - loss: 0.1959 - mse: 0.0703 - mae: 0.1959 - val_loss: 0.2116 - val_mse: 0.0753 - val_mae: 0.2116
# Epoch 68/100
# 41/41 - 0s - loss: 0.1962 - mse: 0.0710 - mae: 0.1962 - val_loss: 0.2133 - val_mse: 0.0733 - val_mae: 0.2133
# Epoch 69/100
# 41/41 - 0s - loss: 0.1954 - mse: 0.0708 - mae: 0.1954 - val_loss: 0.2115 - val_mse: 0.0724 - val_mae: 0.2115
# Epoch 70/100
# 41/41 - 0s - loss: 0.1954 - mse: 0.0700 - mae: 0.1954 - val_loss: 0.2105 - val_mse: 0.0747 - val_mae: 0.2105
# Epoch 71/100
# 41/41 - 0s - loss: 0.1943 - mse: 0.0699 - mae: 0.1943 - val_loss: 0.2095 - val_mse: 0.0736 - val_mae: 0.2095
# Epoch 72/100
# 41/41 - 0s - loss: 0.1946 - mse: 0.0699 - mae: 0.1946 - val_loss: 0.2091 - val_mse: 0.0735 - val_mae: 0.2091
# Epoch 73/100
# 41/41 - 0s - loss: 0.1945 - mse: 0.0699 - mae: 0.1945 - val_loss: 0.2096 - val_mse: 0.0733 - val_mae: 0.2096
# Epoch 74/100
# 41/41 - 0s - loss: 0.1940 - mse: 0.0703 - mae: 0.1940 - val_loss: 0.2110 - val_mse: 0.0753 - val_mae: 0.2110
# Epoch 75/100
# 41/41 - 0s - loss: 0.1931 - mse: 0.0698 - mae: 0.1931 - val_loss: 0.2093 - val_mse: 0.0714 - val_mae: 0.2093
# Epoch 76/100
# 41/41 - 0s - loss: 0.1947 - mse: 0.0704 - mae: 0.1947 - val_loss: 0.2093 - val_mse: 0.0747 - val_mae: 0.2093
# Epoch 77/100
# 41/41 - 0s - loss: 0.1934 - mse: 0.0695 - mae: 0.1934 - val_loss: 0.2186 - val_mse: 0.0825 - val_mae: 0.2186
# Epoch 78/100
# 41/41 - 0s - loss: 0.1981 - mse: 0.0728 - mae: 0.1981 - val_loss: 0.2128 - val_mse: 0.0730 - val_mae: 0.2128
# Epoch 79/100
# 41/41 - 0s - loss: 0.1941 - mse: 0.0700 - mae: 0.1941 - val_loss: 0.2106 - val_mse: 0.0756 - val_mae: 0.2106
# Epoch 80/100
# 41/41 - 0s - loss: 0.1932 - mse: 0.0695 - mae: 0.1932 - val_loss: 0.2088 - val_mse: 0.0727 - val_mae: 0.2088
# Epoch 81/100
# 41/41 - 0s - loss: 0.1943 - mse: 0.0702 - mae: 0.1943 - val_loss: 0.2093 - val_mse: 0.0745 - val_mae: 0.2093
# Epoch 82/100
# 41/41 - 0s - loss: 0.1936 - mse: 0.0700 - mae: 0.1936 - val_loss: 0.2116 - val_mse: 0.0760 - val_mae: 0.2116
# Epoch 83/100
# 41/41 - 0s - loss: 0.1927 - mse: 0.0693 - mae: 0.1927 - val_loss: 0.2091 - val_mse: 0.0741 - val_mae: 0.2091
# Epoch 84/100
# 41/41 - 0s - loss: 0.1931 - mse: 0.0694 - mae: 0.1931 - val_loss: 0.2108 - val_mse: 0.0751 - val_mae: 0.2108
# Epoch 85/100
# 41/41 - 0s - loss: 0.1933 - mse: 0.0693 - mae: 0.1933 - val_loss: 0.2175 - val_mse: 0.0819 - val_mae: 0.2175
# Epoch 86/100
# 41/41 - 0s - loss: 0.1930 - mse: 0.0696 - mae: 0.1930 - val_loss: 0.2120 - val_mse: 0.0770 - val_mae: 0.2120
# Epoch 87/100
# 41/41 - 0s - loss: 0.1972 - mse: 0.0715 - mae: 0.1972 - val_loss: 0.2180 - val_mse: 0.0816 - val_mae: 0.2180
# Epoch 88/100
# 41/41 - 0s - loss: 0.1930 - mse: 0.0691 - mae: 0.1930 - val_loss: 0.2119 - val_mse: 0.0771 - val_mae: 0.2119
# Epoch 89/100
# 41/41 - 0s - loss: 0.1920 - mse: 0.0692 - mae: 0.1920 - val_loss: 0.2093 - val_mse: 0.0738 - val_mae: 0.2093
# Epoch 90/100
# 41/41 - 0s - loss: 0.1932 - mse: 0.0694 - mae: 0.1932 - val_loss: 0.2090 - val_mse: 0.0734 - val_mae: 0.2090
# Epoch 91/100
# 41/41 - 0s - loss: 0.1963 - mse: 0.0720 - mae: 0.1963 - val_loss: 0.2105 - val_mse: 0.0740 - val_mae: 0.2105
# Epoch 92/100
# 41/41 - 0s - loss: 0.1937 - mse: 0.0698 - mae: 0.1937 - val_loss: 0.2092 - val_mse: 0.0744 - val_mae: 0.2092
# Epoch 93/100
# 41/41 - 0s - loss: 0.1934 - mse: 0.0694 - mae: 0.1934 - val_loss: 0.2142 - val_mse: 0.0785 - val_mae: 0.2142
# Epoch 94/100
# 41/41 - 0s - loss: 0.1932 - mse: 0.0694 - mae: 0.1932 - val_loss: 0.2108 - val_mse: 0.0765 - val_mae: 0.2108
# Epoch 95/100
# 41/41 - 0s - loss: 0.1920 - mse: 0.0688 - mae: 0.1920 - val_loss: 0.2092 - val_mse: 0.0736 - val_mae: 0.2092
# Epoch 96/100
# 41/41 - 0s - loss: 0.1928 - mse: 0.0700 - mae: 0.1928 - val_loss: 0.2102 - val_mse: 0.0728 - val_mae: 0.2102
# Epoch 97/100
# 41/41 - 0s - loss: 0.1923 - mse: 0.0694 - mae: 0.1923 - val_loss: 0.2111 - val_mse: 0.0769 - val_mae: 0.2111
# Epoch 98/100
# 41/41 - 0s - loss: 0.1923 - mse: 0.0690 - mae: 0.1923 - val_loss: 0.2139 - val_mse: 0.0787 - val_mae: 0.2139
# Epoch 99/100
# 41/41 - 0s - loss: 0.1932 - mse: 0.0689 - mae: 0.1932 - val_loss: 0.2118 - val_mse: 0.0768 - val_mae: 0.2118
# Epoch 100/100
# 41/41 - 0s - loss: 0.1910 - mse: 0.0685 - mae: 0.1910 - val_loss: 0.2099 - val_mse: 0.0727 - val_mae: 0.2099
# 14.1194803

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'mse', 'mae', 'val_loss', 'val_mse', 'val_mae'])

# %%
# 画出训练集和验证集的损失曲线

import matplotlib.pyplot as plt

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
loss_values50 = loss_values[0:150]
val_loss_values50 = val_loss_values[0:150]
epochs = range(1, len(loss_values50) + 1)
plt.plot(epochs, loss_values50, 'b',color = 'blue', label='Training loss')
plt.plot(epochs, val_loss_values50, 'b',color='orange', label='Validation loss')
plt.rc('font', size = 18)
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.xticks(epochs)
fig = plt.gcf()
fig.set_size_inches(15,7)
#fig.savefig('img/tcstest&validationlosscnn.png', dpi=300)
plt.show()

# %%
# 画出训练集和验证集的误差图像

#mae = history_dict['mean_absolute_error']
#vmae = history_dict['val_mean_absolute_error']
mae = history.history['mae']
vmae = history.history['val_mae']
epochs = range(1, len(mae) + 1)
plt.plot(epochs, mae, 'b',color = 'blue', label='Training error')
plt.plot(epochs, vmae, 'b',color='orange', label='Validation error')
plt.title('Training and validation error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.legend()
plt.xticks(epochs)
fig = plt.gcf()
fig.set_size_inches(15,7)
#fig.savefig('img/tcstest&validationerrorcnn.png', dpi=300)
plt.show()

# %%
model.metrics_names
# Out:
# ['loss', 'mse', 'mae']

# %%
trainScore = model.evaluate(x_train, y_train, verbose=0)
testScore = model.evaluate(x_test, y_test, verbose=0)

# %%
#predicting values for y_test
p = model.predict(x_test)

# %%
plt.plot(y_test, label='y_test')
plt.plot(p, label='prediction')
plt.xlabel('No. of Trading Days')
plt.ylabel('Close Value (scaled)')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(15, 5)
#fig.savefig('img/tcstestcnn.png', dpi=300)
plt.show()

# %%
p1= model.predict(x_train)

# %%
plt.plot(y_train, label='y_train')
x = np.array(range(2578,3223)) #range(x_train shape第一個數字的0.8倍, x_train shape第一個數字)
plt.plot(x,p1[2578:],color = 'magenta',label ='prediction on validating samples') #p1[數字:] 數字代表x_train shape第一個數字的0.8倍
plt.plot(p1[:2578],color='red', label='prediction on training samples')
#x = np.array(range(29512,36890)) #range(x_train shape第一個數字的0.8倍, x_train shape第一個數字)
#plt.plot(x,p1[29512:],color = 'magenta',label ='prediction on validating samples')
#plt.plot(y_train,color='blue', label='y_train')
plt.xlabel('No. of Trading Days')
plt.ylabel('Close Value (scaled)')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(20,10)
#fig.savefig('img/tcstraincnn.png', dpi=300)
plt.show()

# %%
#手動正規化
y = y_test * maxAi   # 原始数据经过除以10000进行缩放，因此乘以10000,返回到原始数据规模
y_pred = p.reshape(806)  # 测试集数据大小为265
y_pred = y_pred * maxAi   # 原始数据经过除以10000进行缩放，因此乘以10000,返回到原始数据规模

# %%
from sklearn.metrics import mean_absolute_error

# %%
print('Trainscore RMSE \tTrain Mean abs Error \tTestscore Rmse \t Test Mean abs Error')
print('%.9f \t\t %.9f \t\t %.9f \t\t %.9f' % (math.sqrt(trainScore[0]),trainScore[1],math.sqrt(testScore[0]),testScore[1]))
# Out:
# Trainscore RMSE 	Train Mean abs Error 	Testscore Rmse 	 Test Mean abs Error
# 0.441757805 		 0.067631468 		 0.422034746 		 0.061824787

# %%
print('mean absolute error \t mean absolute percentage error')
print(' %.9f \t\t\t %.9f' % (mean_absolute_error(y,y_pred),(np.mean(np.abs((y - y_pred) / y)) * 100)))
# Out:
# mean absolute error 	 mean absolute percentage error
#  34732.097810380 			 nan
# C:\Users\joker\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# C:\Users\joker\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %%
Ytrain = y_train * maxAi
Ytest = y_test * maxAi

P1 = p1 * maxAi
PP = p * maxAi

# %%
Y = np.concatenate((Ytrain,Ytest),axis = 0)
plt.plot(Y, label='Y')
P = np.concatenate((P1,PP),axis = 0)
#plotting the complete Y set with predicted values on x_train and x_test(variable p1 & p respectively given above)
#for 
plt.plot(P[:2578],color='red', label='prediction on training samples') #p[:數字] 數字代表x_train shape第一個數字的0.8倍
#for validating samples
z = np.array(range(2578,3223)) #range(x_train shape第一個數字的0.8倍, x_train shape第一個數字)
plt.plot(z,P[2578:3223],color = 'orange',label ='prediction on validating samples') #P[x_train shape第一個數字的0.8倍:x_train shape第一個數字]
#for testing samples
x = np.array(range(3223,4029)) #range(x_train shape第一個數字, x_train shape第一個數字 + x_test shape第一個數字)
plt.plot(x,P[3223:],color = 'purple',label ='prediction on testing samples(x_test)') #p[數字:] 數字代表x_train shape第一個數字

#plt.plot(Y,color='blue', label='Y')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(20,12)
plt.show()

# %%
plt.plot(Ytest[:300], label='y_test')
plt.plot(PP[:300], label='prediction')
plt.title('ONU16 request')
plt.xlabel('Test Case')
plt.ylabel('Ai')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(15, 10)
#fig.savefig('img/tcstestcnn.png', dpi=300)
plt.legend()
plt.show()

# %%
print('timesteps : ',timesteps_)
plt.plot(history.history['mae'])
plt.title('mae')
# Out:
# timesteps :  64
# Text(0.5, 1.0, 'mae')

# %%
print('timesteps : ',timesteps_)
plt.plot(history.history['mse'])
plt.title('mse')
# Out:
# timesteps :  64
# Text(0.5, 1.0, 'mse')

# %%
plt.title('loss')
plt.plot(history.history['loss'])

# %%
model.save('./SelfData_thesis/0701_U20D00_CNN_ONU16_onuAi_195000_2layer_timesteps64.h5', include_optimizer=False)
