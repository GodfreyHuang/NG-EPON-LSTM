# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import datetime
import math
import itertools
from sklearn import preprocessing
import datetime
from sklearn.metrics import mean_squared_error
from math import sqrt
# Out:
# C:\Users\joker\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.

# %%
df1 = pd.read_csv('./SelfData_thesis/0628_self8GData_3to7_ONU16_limitData.csv', usecols=[0], engine='python')
df1.head()
# Out:
#       Ri
# 0   1074
# 1  13514
# 2  14896
# 3    321
# 4    341

# %%
df2 = pd.read_csv('./SelfData_thesis/0628_self8GData_3to7_ONU16_limitData.csv', usecols=[1], engine='python')
df2.head()
# Out:
#       Ai
# 0      0
# 1  12975
# 2  13822
# 3      0
# 4      0

# %%
df3 = pd.read_csv('./SelfData_thesis/0628_self8GData_3to7_ONU16_limitData.csv', usecols=[2], engine='python')
df3.head()
# Out:
#    CycleTime
# 0   0.000367
# 1   0.000399
# 2   0.000415
# 3   0.000375
# 4   0.000424

# %%
df1 = df1.values
df1 = df1.astype('float32')

df2 = df2.values
df2 = df2.astype('float32')

df3 = df3.values
df3 = df3.astype('float32')

# %%
print(np.max(df1))
print(np.max(df2))
print(np.max(df3))

df1Max = np.max(df1)
df2Max = np.max(df2)
#df3Max = np.max(df3)

df1 = df1 / np.max(df1) #手動正規化
df2 = df2 / np.max(df2) #手動正規化
#df3 = df3 / np.max(df3) #手動正規化
# Out:
# 1120017.0
# 439485.0
# 0.00056483

# %%
print(len(df1))
print(len(df2))
print(len(df3))
# Out:
# 13408
# 13408
# 13408

# %%
datasetR = df1
datasetA = df2
datasetT = df3

# %%
# split into train and test sets
train_sizeR = int(len(datasetR) * 0.8) 
test_sizeR = len(datasetR) - train_sizeR
trainR, testR = datasetR[0:train_sizeR], datasetR[train_sizeR:len(datasetR)]

#scaler = MinMaxScaler(feature_range=(0, 1))
#trainR = scaler.fit_transform(trainR)
#testR = scaler.fit_transform(testR)
print(len(trainR), len(testR))
# Out:
# 10726 2682

# %%
# split into train and test sets
train_sizeA = int(len(datasetA) * 0.8) 
test_sizeA = len(datasetA) - train_sizeA
trainA, testA = datasetA[0:train_sizeA], datasetA[train_sizeA:len(datasetA)]

#scaler = MinMaxScaler(feature_range=(0, 1))
#trainR = scaler.fit_transform(trainR)
#testR = scaler.fit_transform(testR)
print(len(trainA), len(testA))
# Out:
# 10726 2682

# %%
# split into train and test sets
train_sizeT = int(len(datasetT) * 0.8) 
test_sizeT = len(datasetT) - train_sizeT
trainT, testT = datasetT[0:train_sizeT], datasetT[train_sizeT:len(datasetT)]

#scaler = MinMaxScaler(feature_range=(0, 1))
#trainR = scaler.fit_transform(trainR)
#testR = scaler.fit_transform(testR)
print(len(trainT), len(testT))
# Out:
# 10726 2682

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 64 #16
trainX_R, trainY_R = create_dataset(trainR, look_back)
testX_R, testY_R = create_dataset(testR, look_back)

trainX_A, trainY_A = create_dataset(trainA, look_back)
testX_A, testY_A = create_dataset(testA, look_back)

trainX_T, trainY_T = create_dataset(trainT, look_back)
testX_T, testY_T = create_dataset(testT, look_back)

# %%
# reshape input to be [samples, time steps, features]
trainX_R = np.reshape(trainX_R, (trainX_R.shape[0], look_back, 1))
testX_R = np.reshape(testX_R, (testX_R.shape[0], look_back, 1))

trainX_A = np.reshape(trainX_A, (trainX_A.shape[0], look_back, 1))
testX_A = np.reshape(testX_A, (testX_A.shape[0], look_back, 1))

trainX_T = np.reshape(trainX_T, (trainX_T.shape[0], look_back, 1))
testX_T = np.reshape(testX_T, (testX_T.shape[0], look_back, 1))
#print(trainX.shape[1])

print(trainX_R.shape)
print(trainY_R.shape)
print(testX_R.shape)
print(testY_R.shape)

print(trainX_A.shape)
print(trainY_A.shape)
print(testX_A.shape)
print(testY_A.shape)

print(trainX_T.shape)
print(trainY_T.shape)
print(testX_T.shape)
print(testY_T.shape)
# Out:
# (10661, 64, 1)
# (10661, 1)
# (2617, 64, 1)
# (2617, 1)
# (10661, 64, 1)
# (10661, 1)
# (2617, 64, 1)
# (2617, 1)
# (10661, 64, 1)
# (10661, 1)
# (2617, 64, 1)
# (2617, 1)

# %%
from __future__ import print_function
import math
#importing keras modules
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Activation ,Dropout , Flatten , Conv1D , MaxPooling1D
from tensorflow.keras.layers import Input, Reshape, concatenate
from tensorflow.keras import losses
from tensorflow.keras import optimizers

# %%
inputs_R = Input(shape=(look_back,))
inputs_A = Input(shape=(look_back,))
inputs_T = Input(shape=(look_back,))

inputs_R_test = Reshape((inputs_R.shape[1], 1))(inputs_R)
inputs_A_test = Reshape((inputs_A.shape[1], 1))(inputs_A)
inputs_T_test = Reshape((inputs_R.shape[1], 1))(inputs_T)

# %%
Ri_1 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(inputs_R_test)
Ri_2 = MaxPooling1D(pool_size=2,padding='valid')(Ri_1)
Ri_3 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(Ri_2)
Ri_4 = MaxPooling1D(pool_size=2,padding='valid')(Ri_3)

Ai_1 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(inputs_A_test)
Ai_2 = MaxPooling1D(pool_size=2,padding='valid')(Ai_1)
Ai_3 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(Ai_2)
Ai_4 = MaxPooling1D(pool_size=2,padding='valid')(Ai_3)

Ti_1 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(inputs_T_test)
Ti_2 = MaxPooling1D(pool_size=2,padding='valid')(Ti_1)
Ti_3 = Conv1D(filters=32,kernel_size=1,padding='same',activation='relu',kernel_initializer="glorot_uniform")(Ti_2)
Ti_4 = MaxPooling1D(pool_size=2,padding='valid')(Ti_3)

Ri_5 = Flatten()(Ri_4)
Ai_5 = Flatten()(Ai_4)
Ti_5 = Flatten()(Ti_4)

out = concatenate([Ri_5, Ai_5, Ti_5], axis = -1)

predictions = Dense(1, activation="relu", kernel_initializer="uniform")(out)

model = Model([inputs_R, inputs_A, inputs_T], outputs = predictions)
model.compile(loss='mse',optimizer='Adam',metrics=['mse','mae'])

# %%
print(model.summary())
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 64)]         0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 64)]         0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 64, 1)        0           input_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 64, 1)        0           input_2[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 64, 1)        0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 64, 32)       64          reshape[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 64, 32)       64          reshape_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 64, 32)       64          reshape_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 32, 32)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 32, 32)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 32, 32)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 32, 32)       1056        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 32, 32)       1056        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 32, 32)       1056        max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 16, 32)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 16, 32)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 16, 32)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 512)          0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1536)         0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            1537        concatenate[0][0]
# ==================================================================================================
# Total params: 4,897
# Trainable params: 4,897
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
from timeit import default_timer as timer
start = timer()
history = model.fit([trainX_R, trainX_A, trainX_T],
                    trainY_A,
                    batch_size=64,
                    epochs=100,
                    validation_split=0.2,
                    verbose=2)
end = timer()
print(end - start)
# Out:
# Epoch 1/100
# 134/134 - 1s - loss: 0.0020 - mse: 0.0020 - mae: 0.0203 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0213
# Epoch 2/100
# 134/134 - 0s - loss: 0.0019 - mse: 0.0019 - mae: 0.0203 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0205
# Epoch 3/100
# 134/134 - 0s - loss: 0.0019 - mse: 0.0019 - mae: 0.0201 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0236
# Epoch 4/100
# 134/134 - 0s - loss: 0.0019 - mse: 0.0019 - mae: 0.0206 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0193
# Epoch 5/100
# 134/134 - 0s - loss: 0.0019 - mse: 0.0019 - mae: 0.0200 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0207
# Epoch 6/100
# 134/134 - 0s - loss: 0.0019 - mse: 0.0019 - mae: 0.0199 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0243
# Epoch 7/100
# 134/134 - 0s - loss: 0.0019 - mse: 0.0019 - mae: 0.0202 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0216
# Epoch 8/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0199 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0196
# Epoch 9/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0198 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0207
# Epoch 10/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0198 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0198
# Epoch 11/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0197 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0198
# Epoch 12/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0198 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0201
# Epoch 13/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0199 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0200
# Epoch 14/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0198 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0189
# Epoch 15/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0197 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0197
# Epoch 16/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0196 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0203
# Epoch 17/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0199 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0189
# Epoch 18/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0197 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0198
# Epoch 19/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0195 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0204
# Epoch 20/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0198 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0185
# Epoch 21/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0196 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0201
# Epoch 22/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0195 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0209
# Epoch 23/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0196 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0225
# Epoch 24/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0196 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0204
# Epoch 25/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0206
# Epoch 26/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0196 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0202
# Epoch 27/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0197 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0184
# Epoch 28/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0217
# Epoch 29/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0196 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0193
# Epoch 30/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0196 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0196
# Epoch 31/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0196 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0190
# Epoch 32/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0199
# Epoch 33/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0196 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0189
# Epoch 34/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0241
# Epoch 35/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0197 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0194
# Epoch 36/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0208
# Epoch 37/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0195 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0190
# Epoch 38/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0207
# Epoch 39/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0189
# Epoch 40/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0191
# Epoch 41/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0214
# Epoch 42/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0195 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0196
# Epoch 43/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0182
# Epoch 44/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0191
# Epoch 45/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0193 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0233
# Epoch 46/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0196 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0191
# Epoch 47/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0193 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0191
# Epoch 48/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0195 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0205
# Epoch 49/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0195 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0193
# Epoch 50/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0195 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0188
# Epoch 51/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0198
# Epoch 52/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0199
# Epoch 53/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0201
# Epoch 54/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0195 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0191
# Epoch 55/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0191
# Epoch 56/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0193 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0199
# Epoch 57/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0193 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0189
# Epoch 58/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0193 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0206
# Epoch 59/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0203
# Epoch 60/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0193 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0208
# Epoch 61/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0206
# Epoch 62/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0190
# Epoch 63/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0193 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0183
# Epoch 64/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0194 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0198
# Epoch 65/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0180
# Epoch 66/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0193 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0194
# Epoch 67/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0188
# Epoch 68/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0192 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0225
# Epoch 69/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0195 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0197
# Epoch 70/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0220
# Epoch 71/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0193 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0181
# Epoch 72/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0193 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0189
# Epoch 73/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0220
# Epoch 74/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0193 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0192
# Epoch 75/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0199
# Epoch 76/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0194
# Epoch 77/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0203
# Epoch 78/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0202
# Epoch 79/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0191 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0195
# Epoch 80/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0195
# Epoch 81/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0201
# Epoch 82/100
# 134/134 - 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0192
# Epoch 83/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0190 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0199
# Epoch 84/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0191 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0209
# Epoch 85/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0202
# Epoch 86/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0193 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0190
# Epoch 87/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0185
# Epoch 88/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0191 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0192
# Epoch 89/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0191 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0189
# Epoch 90/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0190 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0197
# Epoch 91/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0193 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0209
# Epoch 92/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0193
# Epoch 93/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0192 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0189
# Epoch 94/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0191 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0196
# Epoch 95/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0191 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0188
# Epoch 96/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0190 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0201
# Epoch 97/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0191 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0189
# Epoch 98/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0190 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0196
# Epoch 99/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0190 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0191
# Epoch 100/100
# 134/134 - 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0191 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0180
# 40.8064934

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'mse', 'mae', 'val_loss', 'val_mse', 'val_mae'])

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mae'])
plt.title('mae')
# Out:
# timesteps :  64
# Text(0.5, 1.0, 'mae')

# %%
print('timesteps : ', look_back)
plt.plot(history.history['mse'])
plt.title('mse')
# Out:
# timesteps :  64
# Text(0.5, 1.0, 'mse')

# %%
plt.title('loss')
plt.plot(history.history['loss'])

# %%
# 画出训练集和验证集的损失曲线

import matplotlib.pyplot as plt

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
loss_values50 = loss_values[0:150]
val_loss_values50 = val_loss_values[0:150]
epochs = range(1, len(loss_values50) + 1)
plt.plot(epochs, loss_values50, 'b',color = 'blue', label='Training loss')
plt.plot(epochs, val_loss_values50, 'b',color='orange', label='Validation loss')
plt.rc('font', size = 18)
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.xticks(epochs)
fig = plt.gcf()
fig.set_size_inches(15,7)
#fig.savefig('img/tcstest&validationlosscnn.png', dpi=300)
plt.show()

# %%
# 画出训练集和验证集的误差图像

#mae = history_dict['mean_absolute_error']
#vmae = history_dict['val_mean_absolute_error']
mae = history.history['mae']
vmae = history.history['val_mae']
epochs = range(1, len(mae) + 1)
plt.plot(epochs, mae, 'b',color = 'blue', label='Training error')
plt.plot(epochs, vmae, 'b',color='orange', label='Validation error')
plt.title('Training and validation error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.legend()
plt.xticks(epochs)
fig = plt.gcf()
fig.set_size_inches(15,7)
#fig.savefig('img/tcstest&validationerrorcnn.png', dpi=300)
plt.show()

# %%
model.metrics_names

trainScore = model.evaluate([trainX_R, trainX_A, trainX_T], trainY_A, verbose=0)
testScore = model.evaluate([testX_R, testX_A, testX_T], testY_A, verbose=0)

# %%
#predicting values for y_test
p = model.predict([testX_R, testX_A, testX_T])

plt.plot(testY_A, label='y_test')
plt.plot(p, label='prediction')
plt.xlabel('Cycle')
plt.ylabel('predict Ai)')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(15, 5)
#fig.savefig('img/tcstestcnn.png', dpi=300)
plt.show()

# %%
p1 = model.predict([trainX_R, trainX_A, trainX_T])

plt.plot(trainY_A, label='y_train')
x = np.array(range(8528,10661)) #range(x_train shape第一個數字的0.8倍, x_train shape第一個數字)
plt.plot(x,p1[8528:],color = 'magenta',label ='prediction on validating samples') #p1[數字:] 數字代表x_train shape第一個數字的0.8倍
plt.plot(p1[:8528],color='red', label='prediction on training samples')
#x = np.array(range(29512,36890)) #range(x_train shape第一個數字的0.8倍, x_train shape第一個數字)
#plt.plot(x,p1[29512:],color = 'magenta',label ='prediction on validating samples')
#plt.plot(y_train,color='blue', label='y_train')
plt.xlabel('No. of Trading Days')
plt.ylabel('Close Value (scaled)')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(20,10)
#fig.savefig('img/tcstraincnn.png', dpi=300)
plt.show()

# %%
#手動正規化
y = testY_A * df2Max   
y_pred = p.reshape(2617)  
y_pred = y_pred * df2Max   

Ytrain = trainY_A * df2Max
Ytest = testY_A * df2Max

PP = p * df2Max
P1 = p1 * df2Max

# %%
from sklearn.metrics import mean_absolute_error

print('Trainscore RMSE \tTrain Mean abs Error \tTestscore Rmse \t Test Mean abs Error')
print('%.9f \t\t %.9f \t\t %.9f \t\t %.9f' % (math.sqrt(trainScore[0]),trainScore[1],math.sqrt(testScore[0]),testScore[1]))

print('mean absolute error \t mean absolute percentage error')
print(' %.9f \t\t\t %.9f' % (mean_absolute_error(y,y_pred),(np.mean(np.abs((y - y_pred) / y)) * 100)))
# Out:
# Trainscore RMSE 	Train Mean abs Error 	Testscore Rmse 	 Test Mean abs Error
# 0.041956336 		 0.001760334 		 0.033200890 		 0.001102299
# mean absolute error 	 mean absolute percentage error
#  6684.950683594 			 nan
# C:\Users\joker\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   import sys
# C:\Users\joker\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys

# %%
Y = np.concatenate((Ytrain,Ytest),axis = 0)
plt.plot(Y, label='Y')
P = np.concatenate((P1,PP),axis = 0)
#plotting the complete Y set with predicted values on x_train and x_test(variable p1 & p respectively given above)
#for 
plt.plot(P[:8528],color='red', label='prediction on training samples') #p[:數字] 數字代表x_train shape第一個數字的0.8倍
#for validating samples
z = np.array(range(8528,10661)) #range(x_train shape第一個數字的0.8倍, x_train shape第一個數字)
plt.plot(z,P[8528:10661],color = 'orange',label ='prediction on validating samples') #P[x_train shape第一個數字的0.8倍:x_train shape第一個數字]
#for testing samples
x = np.array(range(10661,13278)) #range(x_train shape第一個數字, x_train shape第一個數字 + x_test shape第一個數字)
plt.plot(x,P[10661:],color = 'purple',label ='prediction on testing samples(x_test)') #p[數字:] 數字代表x_train shape第一個數字

#plt.plot(Y,color='blue', label='Y')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(20,12)
plt.show()

# %%
plt.plot(Ytest[:300], label='y_test')
plt.plot(PP[:300], label='prediction')
plt.title('ONU16 request')
plt.xlabel('Test Case')
plt.ylabel('Ai')
plt.legend(loc='upper left')
fig = plt.gcf()
fig.set_size_inches(15, 10)
#fig.savefig('img/tcstestcnn.png', dpi=300)
plt.legend()
plt.show()

# %%
model.save('./SelfData_thesis/0629_U08D00_CNN_ONU16_Ri1120017_Ai439485_CycleTi_onuAi_2layer_timesteps64.h5', include_optimizer=False)
